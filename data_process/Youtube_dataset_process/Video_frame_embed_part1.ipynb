# %%
# !pip install -q transformers torch torchvision opencv-python-headless faiss-cpu yt-dlp pyspark psutil gputil findspark

# !yt-dlp -U
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.3/173.3 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 121.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 95.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 61.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 71.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 106.5 MB/s eta 0:00:00
#   Building wheel for gputil (setup.py) ... done
# Latest version: stable@2025.04.30 from yt-dlp/yt-dlp
# yt-dlp is up to date (stable@2025.04.30 from yt-dlp/yt-dlp)

# %%
# ============================================
# FULL PIPELINE WITH CHECKPOINT PROTECTION
# ============================================
import json
import os
import shutil
import time
import traceback
import subprocess
import tempfile
import random
from datetime import datetime
import glob
import re
import gc
import numpy as np
import pandas as pd
import torch
import faiss
import pickle
import psutil
import GPUtil
import cv2
from transformers import CLIPModel, CLIPProcessor
from PIL import Image
import io

# Define global constants
MAX_PARTITIONS = 4  # Max number of parallel Spark partitions
BATCH_SIZE = 100  # Number of videos to process in each batch
MAX_FRAMES_PER_VIDEO = 30  # Max frames to extract per video
TEMP_DIR = "/content/temp"  # Temporary directory for downloads
LOCAL_INDEX_PATH = "/content/video_embeddings.index"  # Local index path
DRIVE_PROJECT_DIR = "/content/drive/MyDrive/video_embeddings_project"  # Drive project directory
DRIVE_INDEX_PATH = os.path.join(DRIVE_PROJECT_DIR, "video_embeddings.index")  # Drive index path
DRIVE_METADATA_PATH = os.path.join(DRIVE_PROJECT_DIR, "metadata.pkl")  # Drive metadata path
CHECKPOINT_PATH = "/content/checkpoint.pkl"  # Local checkpoint path
DRIVE_CHECKPOINT_PATH = os.path.join(DRIVE_PROJECT_DIR, "checkpoint.pkl")  # Drive checkpoint path
METADATA_PATH = "/content/metadata.pkl"  # Local metadata path

# Download parameters
DOWNLOAD_RETRIES = 3  # Maximum number of retry attempts
DOWNLOAD_DELAY = 2  # Base delay between retries in seconds

# Make sure directories exist
os.makedirs(TEMP_DIR, exist_ok=True)
os.makedirs(DRIVE_PROJECT_DIR, exist_ok=True)

# Initialize model and processor
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch16")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch16")

# Broadcast model state dictionary to worker nodes
try:
    bc_model_state = spark.sparkContext.broadcast(model.state_dict())
    bc_processor = spark.sparkContext.broadcast(processor)
except:
    # For local testing without Spark
    bc_model_state = type('obj', (object,), {'value': model.state_dict()})
    bc_processor = type('obj', (object,), {'value': processor})

# ============================================
# UTILITY FUNCTIONS
# ============================================

def print_memory_usage():
    """Print current memory usage"""
    # RAM
    ram = psutil.virtual_memory()
    ram_used = ram.used / (1024 ** 3)  # GB
    ram_total = ram.total / (1024 ** 3)  # GB
    print(f"RAM: {ram_used:.1f}/{ram_total:.1f} GB ({ram.percent:.1f}%)")

    # GPU if available
    try:
        gpus = GPUtil.getGPUs()
        if gpus:
            gpu = gpus[0]
            print(f"GPU: {gpu.memoryUsed}/{gpu.memoryTotal} MB ({gpu.memoryUtil*100:.1f}%)")
    except:
        pass

def load_checkpoint():
    """Load checkpoint from disk"""
    if os.path.exists(CHECKPOINT_PATH):
        try:
            with open(CHECKPOINT_PATH, 'rb') as f:
                return pickle.load(f)
        except Exception as e:
            print(f"Error loading checkpoint: {e}")

    # If local checkpoint doesn't exist or couldn't be loaded, try Drive
    if os.path.exists(DRIVE_CHECKPOINT_PATH):
        try:
            with open(DRIVE_CHECKPOINT_PATH, 'rb') as f:
                checkpoint = pickle.load(f)
            # Save locally for faster access next time
            with open(CHECKPOINT_PATH, 'wb') as f:
                pickle.dump(checkpoint, f)
            return checkpoint
        except Exception as e:
            print(f"Error loading checkpoint from Drive: {e}")

    # If no checkpoint exists, return empty one
    return {"processed_ids": set(), "last_batch": 0, "index_checkpoints": []}

def save_checkpoint(checkpoint):
    """Save checkpoint to disk"""
    try:
        with open(CHECKPOINT_PATH, 'wb') as f:
            pickle.dump(checkpoint, f)
        return True
    except Exception as e:
        print(f"Error saving checkpoint: {e}")
        return False

def load_metadata():
    """Load metadata from disk"""
    if os.path.exists(METADATA_PATH):
        try:
            with open(METADATA_PATH, 'rb') as f:
                return pickle.load(f)
        except Exception as e:
            print(f"Error loading metadata: {e}")

    # If local metadata doesn't exist or couldn't be loaded, try Drive
    if os.path.exists(DRIVE_METADATA_PATH):
        try:
            with open(DRIVE_METADATA_PATH, 'rb') as f:
                metadata = pickle.load(f)
            # Save locally for faster access next time
            with open(METADATA_PATH, 'wb') as f:
                pickle.dump(metadata, f)
            return metadata
        except Exception as e:
            print(f"Error loading metadata from Drive: {e}")

    # If no metadata exists, return empty list
    return []

def save_metadata(metadata):
    """Save metadata to disk"""
    try:
        with open(METADATA_PATH, 'wb') as f:
            pickle.dump(metadata, f)
        return True
    except Exception as e:
        print(f"Error saving metadata: {e}")
        return False

def sync_to_drive():
    """Sync important files to Google Drive"""
    files_to_sync = [
        (CHECKPOINT_PATH, DRIVE_CHECKPOINT_PATH),
        (METADATA_PATH, DRIVE_METADATA_PATH),
        (LOCAL_INDEX_PATH, DRIVE_INDEX_PATH)
    ]

    for src, dst in files_to_sync:
        if os.path.exists(src):
            try:
                shutil.copy(src, dst)
                print(f"Synced {src} to {dst}")
            except Exception as e:
                print(f"Error syncing {src} to {dst}: {e}")

def check_csv(csv_path):
    """Check if CSV file is valid"""
    try:
        df = pd.read_csv(csv_path)
        if 'video_id' in df.columns or 'video_path' in df.columns:
            return True
        else:
            print("CSV must have either 'video_id' or 'video_path' column")
            return False
    except Exception as e:
        print(f"Error checking CSV: {e}")
        return False

def upload_csv_to_drive(local_csv_path):
    """Upload CSV file to Google Drive"""
    drive_csv_path = os.path.join(DRIVE_PROJECT_DIR, os.path.basename(local_csv_path))
    try:
        shutil.copy(local_csv_path, drive_csv_path)
        print(f"Uploaded {local_csv_path} to {drive_csv_path}")
        return drive_csv_path
    except Exception as e:
        print(f"Error uploading CSV to Drive: {e}")
        return None

# ============================================
# VIDEO PROCESSING FUNCTIONS
# ============================================

def download_video(video_id, retry=0):
    """Download a YouTube video with optimized settings and retries"""
    if retry >= DOWNLOAD_RETRIES:
        print(f"Max retries reached for {video_id}")
        return None

    # Add small delay between retries (and small random component)
    if retry > 0:
        time.sleep(DOWNLOAD_DELAY + random.uniform(0, 1))

    temp_dir = tempfile.mkdtemp()
    output_path = f"{temp_dir}/{video_id}.%(ext)s"
    url = f"https://www.youtube.com/watch?v={video_id}"

    cmd = [
        "yt-dlp",
        "-f", "worst",  # Use worst quality to ensure successful download
        "--cookies","/content/youtube_cookies.txt",
        "--downloader", "native",
        "-o", output_path,
        url
    ]

    try:
        print(f"Attempting download of {video_id} (attempt {retry+1}/{DOWNLOAD_RETRIES})")
        result = subprocess.run(cmd, capture_output=True, text=True)

        # Check if there was an error
        if result.returncode != 0:
            print(f"Error downloading {video_id}: {result.stderr[:200]}...")
            # Retry with exponential backoff
            return download_video(video_id, retry + 1)

        # Check if file was actually downloaded
        for file in os.listdir(temp_dir):
            if file.startswith(video_id):
                file_path = os.path.join(temp_dir, file)
                file_size = os.path.getsize(file_path)
                if file_size < 10000:  # Less than 10KB is probably an error
                    print(f"Downloaded file for {video_id} is too small: {file_size} bytes")
                    os.remove(file_path)
                    # Retry with a different format
                    return download_video(video_id, retry + 1)
                print(f"Successfully downloaded {video_id}: {file_size/1024:.1f}KB")
                return file_path

        print(f"No file found for {video_id} after download command completed")
        return download_video(video_id, retry + 1)

    except Exception as e:
        print(f"Exception while downloading {video_id}: {str(e)}")
        return download_video(video_id, retry + 1)

def test_single_download():
    """Test downloading a single video to verify YouTube connectivity"""
    # Use a reliable, short video for testing
    test_video_id = "jNQXAC9IVRw"  # "Me at the zoo" (first YouTube video)
    print(f"Testing YouTube connectivity with video ID: {test_video_id}")

    path = download_video(test_video_id)
    if path and os.path.exists(path):
        print("✓ YouTube download test successful!")
        try:
            os.remove(path)
            os.rmdir(os.path.dirname(path))
        except:
            pass
        return True
    else:
        print("✗ YouTube download test failed.")
        return False

def extract_frames(video_path, max_frames=MAX_FRAMES_PER_VIDEO):
    """Extract frames from a video"""
    frames = []
    try:
        # Open video
        video = cv2.VideoCapture(video_path)

        # Get video properties
        fps = video.get(cv2.CAP_PROP_FPS)
        total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
        duration = total_frames / fps if fps > 0 else 0

        # Only extract frames from the first 30 seconds
        max_duration = 30.0  # seconds
        frames_to_extract = min(int(fps * min(max_duration, duration)), max_frames)

        # Calculate frame interval to distribute frames evenly
        if frames_to_extract < max_frames:
            interval = 1
        else:
            interval = total_frames // max_frames

        # Extract frames
        frame_count = 0
        frame_idx = 0

        while frame_count < max_frames and frame_idx < total_frames:
            # Set position
            video.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)

            # Read frame
            success, frame = video.read()
            if not success:
                break

            # Convert from BGR to RGB
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

            # Convert to PIL Image
            frame = Image.fromarray(frame)

            # Add to frames list
            frames.append(frame)

            # Update counters
            frame_count += 1
            frame_idx += interval

        # Release video
        video.release()

    except Exception as e:
        print(f"Error extracting frames: {str(e)}")

    return frames

def generate_embeddings(frames, model, processor, device):
    """Generate embeddings for frames"""
    embeddings = []

    try:
        # Process in batches to avoid OOM errors
        batch_size = 8
        for i in range(0, len(frames), batch_size):
            batch_frames = frames[i:i+batch_size]

            # Process frames
            with torch.no_grad():
                inputs = processor(images=batch_frames, return_tensors="pt", padding=True).to(device)
                outputs = model.get_image_features(**inputs)

                # Normalize embeddings
                batch_embeddings = outputs / outputs.norm(dim=-1, keepdim=True)

                # Convert to numpy and add to results
                batch_embeddings = batch_embeddings.cpu().numpy()
                embeddings.extend(batch_embeddings)

    except Exception as e:
        print(f"Error generating embeddings: {str(e)}")

    return embeddings

# ============================================
# VIDEO DOWNLOAD AND PROCESSING FUNCTIONS
# ============================================

# First, let's define a function for sequential downloading
def download_videos_sequentially(video_ids):
    """Download videos one by one with no parallelism"""
    print(f"Downloading {len(video_ids)} videos sequentially (no parallelism)...")

    results = {}
    for idx, video_id in enumerate(video_ids):
        print(f"Downloading video {idx+1}/{len(video_ids)}: {video_id}")
        try:
            path = download_video(video_id)
            results[video_id] = path
            if path:
                print(f"✓ Successfully downloaded {video_id}")
            else:
                print(f"✗ Failed to download {video_id}")

            # Add delay between downloads to avoid rate limiting
            time.sleep(1)
        except Exception as e:
            print(f"Error downloading {video_id}: {str(e)}")
            results[video_id] = None

    print(f"Downloaded {sum(1 for p in results.values() if p)} videos successfully")
    return results

# Fix for the generate_embeddings_in_parallel function to properly handle results
def generate_embeddings_in_parallel(video_paths):
    """Generate embeddings in parallel using Spark for already downloaded videos"""
    if not video_paths:
        print("No videos to process")
        return []

    # Convert dict to list of tuples for Spark
    video_items = [(video_id, path) for video_id, path in video_paths.items() if path]

    if not video_items:
        print("No valid video paths")
        return []

    print(f"Generating embeddings for {len(video_items)} videos using Spark...")

    # Define a helper function that processes partition with shared model
    def process_partition(partition):
        # Load model once per partition using broadcasted state dict
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        items = list(partition)
        print(f"Processing partition with {len(items)} videos on {device}")

        # Initialize fresh model from broadcasted state dict
        model = CLIPModel.from_pretrained("openai/clip-vit-base-patch16")
        model.load_state_dict(bc_model_state.value)
        processor = bc_processor.value

        # Convert to fp16 if using GPU
        if device.type == 'cuda':
            model.half()

        model = model.to(device)
        model.eval()

        results = []
        for video_id, video_path in items:
            try:
                print(f"\nProcessing video: {video_id}")

                # Skip download - videos are already downloaded
                if not os.path.exists(video_path):
                    print(f"✗ {video_id}: Video file not found at {video_path}")
                    continue

                # Extract frames
                frames = extract_frames(video_path)

                if not frames or len(frames) == 0:
                    print(f"✗ {video_id}: No frames extracted")
                    continue

                # Generate embeddings
                embeddings = generate_embeddings(frames, model, processor, device)

                if not embeddings or len(embeddings) == 0:
                    print(f"✗ {video_id}: No embeddings generated")
                    continue

                # Success! Add to results
                frame_indices = list(range(len(embeddings)))
                print(f"✓ {video_id}: Successfully processed {len(embeddings)} frames")
                results.append((video_id, embeddings, frame_indices))

            except Exception as e:
                print(f"✗ {video_id}: Error - {str(e)}")
                traceback.print_exc()

        # Explicitly clear GPU memory after each partition
        del model
        torch.cuda.empty_cache() if torch.cuda.is_available() else None

        return results

    # Create RDD with video items
    num_partitions = min(len(video_items), MAX_PARTITIONS)
    print(f"Using {num_partitions} partitions for {len(video_items)} videos")

    # Create RDD from video items (not just IDs)
    rdd = spark.sparkContext.parallelize(video_items, numSlices=num_partitions)

    # Process using mapPartitions for better efficiency
    start_time = time.time()
    print(f"Starting parallel processing with {num_partitions} partitions")
    results_rdd = rdd.mapPartitions(process_partition)
    all_results = results_rdd.collect()

    # Adaptive flattening - handle both possible Spark return structures
    results = []

    if len(all_results) > 0:
        # Check if we need to flatten (if all_results is a list of lists)
        if isinstance(all_results[0], list):
            # Flatten nested structure
            for partition_results in all_results:
                for result in partition_results:
                    results.append(result)
        else:
            # all_results is already flat
            results = all_results

    elapsed = time.time() - start_time
    print(f"\nProcessed {len(video_items)} videos, got {len(results)} successful results")
    if len(results) > 0:
        print(f"Processing speed: {len(results)/elapsed:.2f} successful videos/second")

    return results

# ============================================
# CHECKPOINT SYSTEM
# ============================================

# Add minimal checkpoint functions
def save_index_checkpoint(index, metadata, batch_idx):
    """Save index checkpoint"""
    if not index or not metadata: return False

    # Create dirs
    os.makedirs(os.path.join(DRIVE_PROJECT_DIR, "checkpoints"), exist_ok=True)
    os.makedirs("/content/checkpoints", exist_ok=True)

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    checkpoint_path = f"/content/checkpoints/index_batch{batch_idx}_{timestamp}.faiss"
    metadata_path = f"/content/checkpoints/metadata_batch{batch_idx}_{timestamp}.json"

    try:
        # Save locally
        faiss.write_index(index, checkpoint_path)
        with open(metadata_path, 'w') as f:
            json.dump(metadata, f)

        # Save to Drive
        drive_path = os.path.join(DRIVE_PROJECT_DIR, "checkpoints", f"index_batch{batch_idx}_{timestamp}.faiss")
        drive_metadata = os.path.join(DRIVE_PROJECT_DIR, "checkpoints", f"metadata_batch{batch_idx}_{timestamp}.json")
        shutil.copy(checkpoint_path, drive_path)
        shutil.copy(metadata_path, drive_metadata)

        # Log checkpoint
        checkpoint = load_checkpoint()
        if "index_checkpoints" not in checkpoint:
            checkpoint["index_checkpoints"] = []

        checkpoint["index_checkpoints"].append({
            "batch_idx": batch_idx,
            "timestamp": timestamp,
            "local_path": checkpoint_path,
            "drive_path": drive_path
        })
        save_checkpoint(checkpoint)

        print(f"✓ Checkpoint saved (batch {batch_idx}, {index.ntotal} embeddings)")
        return True
    except Exception as e:
        print(f"✗ Error saving checkpoint: {e}")
        return False

def find_latest_checkpoint():
    """Find latest checkpoint"""
    checkpoint = load_checkpoint()

    # Try loading from checkpoint registry
    if "index_checkpoints" in checkpoint and checkpoint["index_checkpoints"]:
        checkpoints = sorted(checkpoint["index_checkpoints"], key=lambda x: x.get("timestamp", ""), reverse=True)

        for c in checkpoints:
            if os.path.exists(c.get("local_path", "")):
                metadata_path = c["local_path"].replace("index_", "metadata_")
                return c["local_path"], metadata_path, c["batch_idx"]
            elif os.path.exists(c.get("drive_path", "")):
                local_path = f"/content/checkpoints/restored_index.faiss"
                metadata_path = f"/content/checkpoints/restored_metadata.json"

                # Copy to local
                shutil.copy(c["drive_path"], local_path)
                drive_metadata = c["drive_path"].replace("index_", "metadata_")
                shutil.copy(drive_metadata, metadata_path)

                return local_path, metadata_path, c["batch_idx"]

    # Search for files directly
    local_files = glob.glob("/content/checkpoints/index_batch*.faiss")
    if local_files:
        latest = max(local_files, key=os.path.getctime)
        metadata = latest.replace("index_", "metadata_")
        if os.path.exists(metadata):
            match = re.search(r'batch(\d+)', latest)
            batch_idx = int(match.group(1)) if match else 0
            return latest, metadata, batch_idx

    return None, None, 0

def load_index_checkpoint():
    """Load index from checkpoint"""
    index_path, metadata_path, batch_idx = find_latest_checkpoint()

    if index_path and os.path.exists(index_path):
        try:
            # Load checkpoint
            index = faiss.read_index(index_path)
            with open(metadata_path, 'r') as f:
                metadata = json.load(f)

            # Save as main index
            faiss.write_index(index, LOCAL_INDEX_PATH)
            save_metadata(metadata)

            print(f"✓ Loaded checkpoint (batch {batch_idx}, {index.ntotal} embeddings)")
            return index, metadata, batch_idx
        except Exception as e:
            print(f"✗ Error loading checkpoint: {e}")

    # Fall back to regular loading
    index = None
    if os.path.exists(LOCAL_INDEX_PATH):
        index = faiss.read_index(LOCAL_INDEX_PATH)
    elif os.path.exists(DRIVE_INDEX_PATH):
        index = faiss.read_index(DRIVE_INDEX_PATH)
        faiss.write_index(index, LOCAL_INDEX_PATH)

    metadata = load_metadata()
    return index, metadata, 0

# ============================================
# MAIN PROCESSING FUNCTIONS
# ============================================

# Now fix the process_all_videos function to handle embeddings properly
def process_all_videos(csv_path, total_videos=10000, force_reprocess=False):
    """Process all videos with sequential downloading and parallel embedding generation"""
    overall_start_time = time.time()
    print(f"Starting processing of up to {total_videos} videos")

    # Check if file exists
    if not os.path.exists(csv_path):
        print(f"ERROR: File not found: {csv_path}")
        return None, None

    # Load CSV file
    df = pd.read_csv(csv_path)
    # df = df[6000:]
    # Extract video IDs
    if 'video_path' in df.columns:
        df['video_id'] = df['video_path'].apply(lambda x: str(x).split('.')[0])
    elif 'video_id' not in df.columns:
        print("ERROR: CSV must have either 'video_path' or 'video_id' column")
        return None, None

    # Get all video IDs
    all_video_ids = df['video_id'].tolist()[:total_videos]
    print(f"Found {len(all_video_ids)} videos to process")

    # Load checkpoint or start fresh if force_reprocess
    if not force_reprocess:
        checkpoint = load_checkpoint()
        processed_ids = checkpoint["processed_ids"]
        last_batch = checkpoint["last_batch"]
    else:
        print("Force reprocessing enabled - ignoring checkpoint")
        processed_ids = set()
        last_batch = 0

    # Load index from checkpoint or create new
    index, metadata, _ = load_index_checkpoint()

    # Process in batches
    num_batches = (len(all_video_ids) + BATCH_SIZE - 1) // BATCH_SIZE

    for batch_idx in range(last_batch, num_batches):
        start_idx = batch_idx * BATCH_SIZE
        end_idx = min(start_idx + BATCH_SIZE, len(all_video_ids))

        # Get videos for this batch (skip already processed ones)
        batch_videos = [vid for vid in all_video_ids[start_idx:end_idx]
                        if vid not in processed_ids]

        if not batch_videos:
            print(f"Batch {batch_idx+1}/{num_batches} already processed, skipping")
            continue

        print(f"\n{'='*60}")
        print(f"PROCESSING BATCH {batch_idx+1}/{num_batches}")
        print(f"{'='*60}")
        print(f"Videos in this batch: {len(batch_videos)}")
        print(f"First few videos: {batch_videos[:5]}")
        print_memory_usage()

        # Process this batch with timing
        batch_start = time.time()
        print(f"Batch {batch_idx+1}: Starting processing at {datetime.now().strftime('%H:%M:%S')}")

        # STEP 1: Download videos sequentially
        video_paths = download_videos_sequentially(batch_videos)

        # STEP 2: Generate embeddings in parallel with Spark
        batch_results = generate_embeddings_in_parallel(video_paths)

        # Cleanup downloaded videos
        for path in video_paths.values():
            if path and os.path.exists(path):
                try:
                    os.remove(path)
                    parent_dir = os.path.dirname(path)
                    if parent_dir != TEMP_DIR and os.path.exists(parent_dir):
                        os.rmdir(parent_dir)
                except:
                    pass

        batch_time = time.time() - batch_start
        print(f"Batch {batch_idx+1}: Processed {len(batch_results)}/{len(batch_videos)} videos in {batch_time:.2f}s")

        # Mark ALL videos as processed
        for video_id in batch_videos:
            processed_ids.add(video_id)

        # Create batch metadata and collect embeddings
        batch_metadata = []
        all_embeddings = []

        # Timing embedding aggregation
        t_agg = time.time()

        # Process results with safety check
        for result in batch_results:
            try:
                # Validate result structure
                if not isinstance(result, tuple) or len(result) != 3:
                    print(f"WARNING: Skipping result with invalid structure (expected 3 elements)")
                    continue

                video_id, embeddings, frame_indices = result

                # Add embeddings
                for i, embedding in enumerate(embeddings):
                    all_embeddings.append(embedding)
                    batch_metadata.append({
                        'video_id': video_id,
                        'frame_idx': frame_indices[i],
                        'embedding_idx': len(metadata) + len(batch_metadata) - 1
                    })
            except Exception as e:
                print(f"Error processing result: {e}")
                continue

        print(f"Aggregated {len(all_embeddings)} embeddings in {time.time()-t_agg:.2f}s")

        # Add to FAISS index
        if all_embeddings:
            t_index = time.time()
            print(f"Adding {len(all_embeddings)} new embeddings to index")
            embeddings_array = np.array(all_embeddings).astype('float32')

            if index is None:
                # Create index
                dim = embeddings_array.shape[1]
                print(f"Creating new FAISS index with dimension {dim}")
                index = faiss.IndexFlatIP(dim)

            # Add to index
            index.add(embeddings_array)

            # Save index locally
            print(f"Saving local index with {index.ntotal} total embeddings")
            faiss.write_index(index, LOCAL_INDEX_PATH)

            # Update metadata
            metadata.extend(batch_metadata)
            save_metadata(metadata)

            print(f"Index operations took {time.time()-t_index:.2f}s")

            # Save checkpoint
            save_index_checkpoint(index, metadata, batch_idx)

            # Sync to Drive
            t_sync = time.time()
            print("Syncing index and metadata to Drive...")
            sync_to_drive()
            print(f"Sync to Drive completed in {time.time()-t_sync:.2f}s")

        # Save processing checkpoint
        checkpoint = {
            "processed_ids": processed_ids,
            "last_batch": batch_idx + 1
        }
        save_checkpoint(checkpoint)
        print(f"Checkpoint saved at batch {batch_idx+1}")

        # Clean up memory
        del all_embeddings
        del batch_results
        if 'embeddings_array' in locals():
            del embeddings_array

        # Force garbage collection
        gc.collect()
        torch.cuda.empty_cache() if torch.cuda.is_available() else None

        # Overall progress
        overall_progress = len(processed_ids) / len(all_video_ids) * 100
        elapsed = time.time() - overall_start_time
        eta = (elapsed / (batch_idx - last_batch + 1)) * (num_batches - batch_idx - 1) if batch_idx > last_batch else 0

        print(f"\nOverall progress: {len(processed_ids)}/{len(all_video_ids)} videos ({overall_progress:.1f}%)")
        print(f"Elapsed time: {elapsed/3600:.2f} hours")
        print(f"Estimated remaining time: {eta/3600:.2f} hours")
        print(f"{'='*60}\n")

    # Final sync to Drive
    sync_to_drive()

    # Load final index to return
    if os.path.exists(LOCAL_INDEX_PATH):
        index = faiss.read_index(LOCAL_INDEX_PATH)
        print(f"Final index size: {index.ntotal} embeddings")
    else:
        index = None

    total_time = time.time() - overall_start_time
    print(f"Total processing time: {total_time/3600:.2f} hours")
    return index, metadata

# Update the run_pipeline function to use our new approach
def run_pipeline(csv_path=None, batch_size=None, video_limit=None, force_reprocess=False):
    """Run the pipeline with the specified parameters"""
    print("\n" + "="*70)
    print("VIDEO EMBEDDING PIPELINE WITH HYBRID APPROACH")
    print("="*70)

    # Check GPU
    try:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        print(f"Using device: {device}")
        if torch.cuda.is_available():
            print(f"GPU: {torch.cuda.get_device_name(0)}")
            print(f"Optimizations: FP16=True, Fast CLIP model=True")
            print(f"Frame extraction: First 30 seconds only (max {MAX_FRAMES_PER_VIDEO} frames)")
    except:
        print("Could not detect GPU")

    # Initial memory usage
    print("\nInitial memory usage:")
    print_memory_usage()

    # Override batch size if specified
    if batch_size is not None:
        global BATCH_SIZE
        BATCH_SIZE = batch_size
        print(f"Using custom batch size: {BATCH_SIZE}")

    # Test video download to verify YouTube connectivity
    test_download_result = test_single_download()
    if not test_download_result:
        print("\nWARNING: Initial download test failed. Processing may encounter issues.")
        user_input = input("Do you want to continue anyway? (y/n): ")
        if user_input.lower() != 'y':
            print("Aborting pipeline.")
            return

    # Determine CSV path
    if csv_path is None:
        # Check if we have a CSV already in Google Drive
        drive_csv_path = os.path.join(DRIVE_PROJECT_DIR, "all_videos.csv")
        local_csv_path = '/content/all_videos.csv'

        csv_path_to_use = None

        # First check Drive
        if os.path.exists(drive_csv_path):
            print(f"Found CSV in Google Drive: {drive_csv_path}")
            csv_path_to_use = drive_csv_path
        # Then check local
        elif os.path.exists(local_csv_path):
            print(f"Found CSV locally, uploading to Drive")
            drive_csv_path = upload_csv_to_drive(local_csv_path)
            if drive_csv_path:
                csv_path_to_use = drive_csv_path
            else:
                csv_path_to_use = local_csv_path
        else:
            print("No CSV file found. Please upload a CSV file with video IDs.")
            return
    else:
        csv_path_to_use = csv_path

    # Run processing
    if csv_path_to_use and check_csv(csv_path_to_use):
        total_videos = video_limit if video_limit else 10000
        print(f"\nStarting processing of up to {total_videos} videos")
        print(f"Using batch size: {BATCH_SIZE}")
        print(f"Using hybrid approach: Sequential downloads + Parallel embeddings")
        print(f"Force reprocessing: {force_reprocess}")
        print(f"All results will be saved to both local storage and Google Drive")

        index, metadata = process_all_videos(csv_path_to_use, total_videos=total_videos,
                                           force_reprocess=force_reprocess)

        # Final cleanup
        del index
        del metadata
        gc.collect()
        torch.cuda.empty_cache() if torch.cuda.is_available() else None

        print("\nProcessing complete! FAISS index created.")
        print(f"Index path: {DRIVE_INDEX_PATH}")
        print(f"Metadata path: {DRIVE_METADATA_PATH}")
        print("\nTo search: search_by_text('your query here')")

        # Final memory usage
        print("\nFinal memory usage:")
        print_memory_usage()
    else:
        print("\nPlease upload a valid CSV file with video IDs before running.")

# ============================================
# SEARCH FUNCTIONALITY
# ============================================

def search_by_text(query, top_k=5):
    """Search for videos by text query"""
    # Load index and metadata
    if not os.path.exists(LOCAL_INDEX_PATH):
        if os.path.exists(DRIVE_INDEX_PATH):
            shutil.copy(DRIVE_INDEX_PATH, LOCAL_INDEX_PATH)
        else:
            print("ERROR: Index not found")
            return []

    # Load metadata
    metadata = load_metadata()
    if not metadata:
        print("ERROR: Metadata not found")
        return []

    # Load index
    index = faiss.read_index(LOCAL_INDEX_PATH)

    # Load model and processor
    model = CLIPModel.from_pretrained("openai/clip-vit-base-patch16")
    processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch16")

    # Generate text embedding
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    model.eval()

    with torch.no_grad():
        inputs = processor(text=[query], return_tensors="pt", padding=True).to(device)
        text_embedding = model.get_text_features(**inputs)
        text_embedding = text_embedding / text_embedding.norm(dim=-1, keepdim=True)
        text_embedding = text_embedding.cpu().numpy().astype('float32')

    # Search index
    D, I = index.search(text_embedding, top_k)

    # Prepare results
    results = []
    for i, (score, idx) in enumerate(zip(D[0], I[0])):
        if idx < len(metadata):
            entry = metadata[idx]
            video_id = entry['video_id']
            results.append({
                'rank': i+1,
                'video_id': video_id,
                'frame_idx': entry['frame_idx'],
                'score': float(score),
                'link': f"https://www.youtube.com/watch?v={video_id}"
            })

    return results
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/4.10k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/599M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/599M [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/905 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/961k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]

# %%
from pyspark.sql import SparkSession
import findspark
import warnings

# Initialize Spark
def initialize_spark():
    """Initialize Spark session"""
    print("Initializing Spark...")

    try:
        # Try to initialize findspark to locate Spark installation
        try:
            findspark.init()
            print(" Successfully initialized findspark")
        except:
            print(" Failed to initialize findspark, will try direct SparkSession creation")
            pass

        # Create Spark session
        spark = SparkSession.builder \
            .appName("VideoEmbeddingPipeline") \
            .config("spark.driver.memory", "4g") \
            .config("spark.executor.memory", "4g") \
            .config("spark.dynamicAllocation.enabled", "false") \
            .config("spark.driver.maxResultSize", "2g") \
            .getOrCreate()

        # Suppress Spark warnings
        warnings.filterwarnings("ignore")
        spark.sparkContext.setLogLevel("ERROR")

        # Set global variable
        globals()['spark'] = spark

        # Print successful initialization
        print(f" Successfully initialized Spark {spark.version}")
        print(f" Using {spark.sparkContext.defaultParallelism} cores")

        return spark

    except Exception as e:
        print(f" Error initializing Spark: {e}")
        print("Falling back to single-node processing...")

        # Create a dummy Spark object for testing
        class DummySparkContext:
            def parallelize(self, data, numSlices=1):
                return DummyRDD(data)

            def broadcast(self, data):
                return type('obj', (object,), {'value': data})

        class DummyRDD:
            def __init__(self, data):
                self.data = data

            def mapPartitions(self, func):
                # Process all data as a single partition
                result = func(self.data)
                return DummyRDD([result])

            def collect(self):
                return self.data

        class DummySparkSession:
            def __init__(self):
                self.sparkContext = DummySparkContext()
                self.version = "DUMMY"

        dummy_spark = DummySparkSession()
        globals()['spark'] = dummy_spark

        print("Using dummy Spark session for single-node processing")
        return dummy_spark

def update_checkpoint_registry():
    """Update checkpoint registry to include files in the checkpoints directory"""
    print("\n===== UPDATING CHECKPOINT REGISTRY =====")

    # Load existing checkpoint
    print(f"Loading existing checkpoint from: {CHECKPOINT_PATH}")
    try:
        with open(CHECKPOINT_PATH, 'rb') as f:
            checkpoint = pickle.load(f)

        print(f"Current checkpoint info:")
        print(f"  Last batch: {checkpoint.get('last_batch', 'Not found')}")
        print(f"  Processed videos: {len(checkpoint.get('processed_ids', set()))}")
        print(f"  Index checkpoints: {len(checkpoint.get('index_checkpoints', []))}")
    except Exception as e:
        print(f"Error loading checkpoint: {e}")
        print("Creating new checkpoint...")
        checkpoint = {
            "processed_ids": set(),
            "last_batch": 0,
            "index_checkpoints": []
        }

    # Find all FAISS files in checkpoints directory
    drive_checkpoints_dir = os.path.join(DRIVE_PROJECT_DIR, "checkpoints")
    print(f"\nScanning for checkpoint files in: {drive_checkpoints_dir}")

    if not os.path.exists(drive_checkpoints_dir):
        print(f"  ✗ Checkpoint directory not found")
        return checkpoint

    faiss_files = glob.glob(os.path.join(drive_checkpoints_dir, "index_batch*.faiss"))
    print(f"  Found {len(faiss_files)} FAISS checkpoint files")

    # Track highest batch number
    highest_batch = checkpoint.get("last_batch", 0)

    # Process each FAISS file
    for faiss_file in faiss_files:
        filename = os.path.basename(faiss_file)
        match = re.search(r'batch(\d+)_(\d{8}_\d{6})', filename)
        if match:
            batch_idx = int(match.group(1))
            timestamp = match.group(2)

            # Update highest batch if needed
            highest_batch = max(highest_batch, batch_idx)

            # Check if this file is already registered
            file_exists = False
            for entry in checkpoint.get("index_checkpoints", []):
                if os.path.basename(entry.get("drive_path", "")) == filename:
                    file_exists = True
                    break

            if not file_exists:
                # Find corresponding metadata file
                metadata_file = faiss_file.replace("index_", "metadata_")

                if os.path.exists(metadata_file):
                    # Create local paths
                    local_faiss = os.path.join("/content/checkpoints", filename)
                    local_metadata = os.path.join("/content/checkpoints", os.path.basename(metadata_file))

                    # Add to checkpoint registry
                    entry = {
                        "batch_idx": batch_idx,
                        "timestamp": timestamp,
                        "local_path": local_faiss,
                        "drive_path": faiss_file
                    }

                    checkpoint.setdefault("index_checkpoints", []).append(entry)
                    print(f"  Added checkpoint for batch {batch_idx} to registry")

                    # Try to load metadata to get processed IDs
                    try:
                        with open(metadata_file, 'r') as f:
                            metadata = json.load(f)

                        # Extract video IDs from metadata
                        for item in metadata:
                            if 'video_id' in item:
                                checkpoint.setdefault("processed_ids", set()).add(item['video_id'])
                    except Exception as e:
                        print(f"  Error loading metadata from {metadata_file}: {e}")

    # Update last_batch if needed
    if highest_batch > checkpoint.get("last_batch", 0):
        print(f"\nUpdating last_batch from {checkpoint.get('last_batch', 0)} to {highest_batch}")
        checkpoint["last_batch"] = highest_batch

    # Sort checkpoints by timestamp
    checkpoint["index_checkpoints"] = sorted(
        checkpoint.get("index_checkpoints", []),
        key=lambda x: x.get("timestamp", ""),
        reverse=True
    )

    # Save updated checkpoint
    print("\nSaving updated checkpoint...")
    with open(CHECKPOINT_PATH, 'wb') as f:
        pickle.dump(checkpoint, f)

    # Save to Drive
    with open(DRIVE_CHECKPOINT_PATH, 'wb') as f:
        pickle.dump(checkpoint, f)

    print(f"Checkpoint updated and saved!")
    print(f"Last batch: {checkpoint['last_batch']}")
    print(f"Processed videos: {len(checkpoint.get('processed_ids', set()))}")
    print(f"Index checkpoints: {len(checkpoint['index_checkpoints'])}")

    return checkpoint

# Function to run pipeline with updated checkpoint
def run_pipeline_with_updated_checkpoint(csv_path=None, batch_size=None, video_limit=None, force_reprocess=False):
    """Run the pipeline with an updated checkpoint registry"""
    print("\n" + "="*70)
    print("VIDEO EMBEDDING PIPELINE WITH CHECKPOINT UPDATE")
    print("="*70)

    initialize_spark()

    # Create checkpoints directory if it doesn't exist
    os.makedirs("/content/checkpoints", exist_ok=True)
    os.makedirs(os.path.join(DRIVE_PROJECT_DIR, "checkpoints"), exist_ok=True)

    # Update checkpoint registry
    print("Checking and updating checkpoint registry...")
    checkpoint = update_checkpoint_registry()

    print(f"\nCheckpoint registry updated. Pipeline will resume from batch {checkpoint['last_batch'] + 1}")
    print(f"Would you like to continue? (y/n)")

    choice = input().lower()
    if not choice.startswith('y'):
        print("Aborting pipeline.")
        return

    # Continue with normal pipeline
    return run_pipeline(csv_path, batch_size, video_limit, force_reprocess)

# %%
run_pipeline_with_updated_checkpoint('/content/all_videos.csv', batch_size=100, video_limit=6000, force_reprocess=False)
# Out:
# ======================================================================
# VIDEO EMBEDDING PIPELINE WITH CHECKPOINT UPDATE
# ======================================================================
# Initializing Spark...
#  Successfully initialized findspark
#  Successfully initialized Spark 3.5.5
#  Using 2 cores
# Checking and updating checkpoint registry...
#
# ===== UPDATING CHECKPOINT REGISTRY =====
# Loading existing checkpoint from: /content/checkpoint.pkl
# Current checkpoint info:
#   Last batch: 21
#   Processed videos: 700
#   Index checkpoints: 0
#
# Scanning for checkpoint files in: /content/drive/MyDrive/video_embeddings_project/checkpoints
#   Found 21 FAISS checkpoint files
#
# Saving updated checkpoint...
# Checkpoint updated and saved!
# Last batch: 21
# Processed videos: 700
# Index checkpoints: 0
#
# Checkpoint registry updated. Pipeline will resume from batch 22
# Would you like to continue? (y/n)
# y
#
# ======================================================================
# VIDEO EMBEDDING PIPELINE WITH HYBRID APPROACH
# ======================================================================
# Using device: cuda
# GPU: Tesla T4
# Optimizations: FP16=True, Fast CLIP model=True
# Frame extraction: First 30 seconds only (max 30 frames)
#
# Initial memory usage:
# RAM: 4.6/12.7 GB (38.7%)
# GPU: 758.0/15360.0 MB (4.9%)
# Using custom batch size: 100
# Testing YouTube connectivity with video ID: jNQXAC9IVRw
# Attempting download of jNQXAC9IVRw (attempt 1/3)
# Successfully downloaded jNQXAC9IVRw: 772.8KB
# ✓ YouTube download test successful!
#
# Starting processing of up to 6000 videos
# Using batch size: 100
# Using hybrid approach: Sequential downloads + Parallel embeddings
# Force reprocessing: False
# All results will be saved to both local storage and Google Drive
# Starting processing of up to 6000 videos
# Found 6000 videos to process
#
# ============================================================
# PROCESSING BATCH 22/60
# ============================================================
# Videos in this batch: 100
# First few videos: ['00IXIrxLph8', '6CNoe0HegLk', '00KiNuZYwlY', 'wZHivT81Wd8', 'K5LCmT-WfTs']
# RAM: 4.7/12.7 GB (40.0%)
# GPU: 758.0/15360.0 MB (4.9%)
# Batch 22: Starting processing at 19:16:41
# Downloading 100 videos sequentially (no parallelism)...
# Downloading video 1/100: 00IXIrxLph8
# Attempting download of 00IXIrxLph8 (attempt 1/3)
# Successfully downloaded 00IXIrxLph8: 23698.6KB
# ✓ Successfully downloaded 00IXIrxLph8
# Downloading video 2/100: 6CNoe0HegLk
# Attempting download of 6CNoe0HegLk (attempt 1/3)
# Successfully downloaded 6CNoe0HegLk: 8774.4KB
# ✓ Successfully downloaded 6CNoe0HegLk
# Downloading video 3/100: 00KiNuZYwlY
# Attempting download of 00KiNuZYwlY (attempt 1/3)
# Successfully downloaded 00KiNuZYwlY: 26018.6KB
# ✓ Successfully downloaded 00KiNuZYwlY
# Downloading video 4/100: wZHivT81Wd8
# Attempting download of wZHivT81Wd8 (attempt 1/3)
# Successfully downloaded wZHivT81Wd8: 31114.8KB
# ✓ Successfully downloaded wZHivT81Wd8
# Downloading video 5/100: K5LCmT-WfTs
# Attempting download of K5LCmT-WfTs (attempt 1/3)
# Successfully downloaded K5LCmT-WfTs: 7914.6KB
# ✓ Successfully downloaded K5LCmT-WfTs
# Downloading video 6/100: wzHjHs6jlIA
# Attempting download of wzHjHs6jlIA (attempt 1/3)
# Successfully downloaded wzHjHs6jlIA: 1893.2KB
# ✓ Successfully downloaded wzHjHs6jlIA
# Downloading video 7/100: RojAh9UO7NE
# Attempting download of RojAh9UO7NE (attempt 1/3)
# Successfully downloaded RojAh9UO7NE: 42557.1KB
# ✓ Successfully downloaded RojAh9UO7NE
# Downloading video 8/100: WZHmri9FRWA
# Attempting download of WZHmri9FRWA (attempt 1/3)
# Successfully downloaded WZHmri9FRWA: 12971.2KB
# ✓ Successfully downloaded WZHmri9FRWA
# Downloading video 9/100: RoJI0KfJXB8
# Attempting download of RoJI0KfJXB8 (attempt 1/3)
# Error downloading RoJI0KfJXB8: ERROR: [youtube] RoJI0KfJXB8: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of RoJI0KfJXB8 (attempt 2/3)
# Error downloading RoJI0KfJXB8: ERROR: [youtube] RoJI0KfJXB8: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of RoJI0KfJXB8 (attempt 3/3)
# Error downloading RoJI0KfJXB8: ERROR: [youtube] RoJI0KfJXB8: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Max retries reached for RoJI0KfJXB8
# ✗ Failed to download RoJI0KfJXB8
# Downloading video 10/100: u3rQbn3OWuc
# Attempting download of u3rQbn3OWuc (attempt 1/3)
# Error downloading u3rQbn3OWuc: ERROR: [youtube] u3rQbn3OWuc: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of u3rQbn3OWuc (attempt 2/3)
# Error downloading u3rQbn3OWuc: ERROR: [youtube] u3rQbn3OWuc: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of u3rQbn3OWuc (attempt 3/3)
# Error downloading u3rQbn3OWuc: ERROR: [youtube] u3rQbn3OWuc: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Max retries reached for u3rQbn3OWuc
# ✗ Failed to download u3rQbn3OWuc
# Downloading video 11/100: k5m8n1CvI-U
# Attempting download of k5m8n1CvI-U (attempt 1/3)
# Successfully downloaded k5m8n1CvI-U: 21993.9KB
# ✓ Successfully downloaded k5m8n1CvI-U
# Downloading video 12/100: wzhwTnkKWzs
# Attempting download of wzhwTnkKWzs (attempt 1/3)
# Successfully downloaded wzhwTnkKWzs: 9380.0KB
# ✓ Successfully downloaded wzhwTnkKWzs
# Downloading video 13/100: KHMMzaatY_E
# Attempting download of KHMMzaatY_E (attempt 1/3)
# Successfully downloaded KHMMzaatY_E: 5060.1KB
# ✓ Successfully downloaded KHMMzaatY_E
# Downloading video 14/100: KHmQZX9XGd0
# Attempting download of KHmQZX9XGd0 (attempt 1/3)
# Successfully downloaded KHmQZX9XGd0: 4943.7KB
# ✓ Successfully downloaded KHmQZX9XGd0
# Downloading video 15/100: XE5BKx-Tmeg
# Attempting download of XE5BKx-Tmeg (attempt 1/3)
# Successfully downloaded XE5BKx-Tmeg: 4169.6KB
# ✓ Successfully downloaded XE5BKx-Tmeg
# Downloading video 16/100: KHMTi13obto
# Attempting download of KHMTi13obto (attempt 1/3)
# Successfully downloaded KHMTi13obto: 8381.8KB
# ✓ Successfully downloaded KHMTi13obto
# Downloading video 17/100: OvYbezJeDDs
# Attempting download of OvYbezJeDDs (attempt 1/3)
# Successfully downloaded OvYbezJeDDs: 3926.9KB
# ✓ Successfully downloaded OvYbezJeDDs
# Downloading video 18/100: ryeADOEu7Dc
# Attempting download of ryeADOEu7Dc (attempt 1/3)
# Error downloading ryeADOEu7Dc: ERROR: [youtube] ryeADOEu7Dc: Video unavailable. This video is no longer available due to a copyright claim by Maangchi
# ...
# Attempting download of ryeADOEu7Dc (attempt 2/3)
# Error downloading ryeADOEu7Dc: ERROR: [youtube] ryeADOEu7Dc: Video unavailable. This video is no longer available due to a copyright claim by Maangchi
# ...
# Attempting download of ryeADOEu7Dc (attempt 3/3)
# Error downloading ryeADOEu7Dc: ERROR: [youtube] ryeADOEu7Dc: Video unavailable. This video is no longer available due to a copyright claim by Maangchi
# ...
# Max retries reached for ryeADOEu7Dc
# ✗ Failed to download ryeADOEu7Dc
# Downloading video 19/100: wW1SA8e6aRw
# Attempting download of wW1SA8e6aRw (attempt 1/3)
# Successfully downloaded wW1SA8e6aRw: 21047.6KB
# ✓ Successfully downloaded wW1SA8e6aRw
# Downloading video 20/100: ZQvLxyb7E9I
# Attempting download of ZQvLxyb7E9I (attempt 1/3)
# Successfully downloaded ZQvLxyb7E9I: 18438.1KB
# ✓ Successfully downloaded ZQvLxyb7E9I
# Downloading video 21/100: zQVqjTVtUlg
# Attempting download of zQVqjTVtUlg (attempt 1/3)
# Successfully downloaded zQVqjTVtUlg: 23439.0KB
# ✓ Successfully downloaded zQVqjTVtUlg
# Downloading video 22/100: wW2gl-9dBdk
# Attempting download of wW2gl-9dBdk (attempt 1/3)
# Successfully downloaded wW2gl-9dBdk: 22210.6KB
# ✓ Successfully downloaded wW2gl-9dBdk
# Downloading video 23/100: WW3NKIbzhJA
# Attempting download of WW3NKIbzhJA (attempt 1/3)
# Successfully downloaded WW3NKIbzhJA: 15457.3KB
# ✓ Successfully downloaded WW3NKIbzhJA
# Downloading video 24/100: WW3PnuPOtM4
# Attempting download of WW3PnuPOtM4 (attempt 1/3)
# Successfully downloaded WW3PnuPOtM4: 9222.8KB
# ✓ Successfully downloaded WW3PnuPOtM4
# Downloading video 25/100: _Ww44bZ327c
# Attempting download of _Ww44bZ327c (attempt 1/3)
# Successfully downloaded _Ww44bZ327c: 32890.3KB
# ✓ Successfully downloaded _Ww44bZ327c
# Downloading video 26/100: ZqWUk94uZYU
# Attempting download of ZqWUk94uZYU (attempt 1/3)
# Successfully downloaded ZqWUk94uZYU: 14085.9KB
# ✓ Successfully downloaded ZqWUk94uZYU
# Downloading video 27/100: ww46JYNFz3A
# Attempting download of ww46JYNFz3A (attempt 1/3)
# Successfully downloaded ww46JYNFz3A: 18027.4KB
# ✓ Successfully downloaded ww46JYNFz3A
# Downloading video 28/100: 340TDvayG68
# Attempting download of 340TDvayG68 (attempt 1/3)
# Successfully downloaded 340TDvayG68: 45428.0KB
# ✓ Successfully downloaded 340TDvayG68
# Downloading video 29/100: 94d7ZXySplo
# Attempting download of 94d7ZXySplo (attempt 1/3)
# Successfully downloaded 94d7ZXySplo: 51835.4KB
# ✓ Successfully downloaded 94d7ZXySplo
# Downloading video 30/100: f_R-217N_qg
# Attempting download of f_R-217N_qg (attempt 1/3)
# Successfully downloaded f_R-217N_qg: 33723.8KB
# ✓ Successfully downloaded f_R-217N_qg
# Downloading video 31/100: 94D8RE5hGzs
# Attempting download of 94D8RE5hGzs (attempt 1/3)
# Error downloading 94D8RE5hGzs: ERROR: [youtube] 94D8RE5hGzs: This video has been removed for violating YouTube's Community Guidelines
# ...
# Attempting download of 94D8RE5hGzs (attempt 2/3)
# Error downloading 94D8RE5hGzs: ERROR: [youtube] 94D8RE5hGzs: This video has been removed for violating YouTube's Community Guidelines
# ...
# Attempting download of 94D8RE5hGzs (attempt 3/3)
# Error downloading 94D8RE5hGzs: ERROR: [youtube] 94D8RE5hGzs: This video has been removed for violating YouTube's Community Guidelines
# ...
# Max retries reached for 94D8RE5hGzs
# ✗ Failed to download 94D8RE5hGzs
# Downloading video 32/100: fr2bfBWiwfA
# Attempting download of fr2bfBWiwfA (attempt 1/3)
# Successfully downloaded fr2bfBWiwfA: 75653.3KB
# ✓ Successfully downloaded fr2bfBWiwfA
# Downloading video 33/100: 342sNQ-NPmc
# Attempting download of 342sNQ-NPmc (attempt 1/3)
# Successfully downloaded 342sNQ-NPmc: 13882.8KB
# ✓ Successfully downloaded 342sNQ-NPmc
# Downloading video 34/100: fR2Kqt74_os
# Attempting download of fR2Kqt74_os (attempt 1/3)
# Successfully downloaded fR2Kqt74_os: 20160.5KB
# ✓ Successfully downloaded fR2Kqt74_os
# Downloading video 35/100: 342WGBSovNg
# Attempting download of 342WGBSovNg (attempt 1/3)
# Error downloading 342WGBSovNg: ERROR: [youtube] 342WGBSovNg: Video unavailable
# ...
# Attempting download of 342WGBSovNg (attempt 2/3)
# Error downloading 342WGBSovNg: ERROR: [youtube] 342WGBSovNg: Video unavailable
# ...
# Attempting download of 342WGBSovNg (attempt 3/3)
# Error downloading 342WGBSovNg: ERROR: [youtube] 342WGBSovNg: Video unavailable
# ...
# Max retries reached for 342WGBSovNg
# ✗ Failed to download 342WGBSovNg
# Downloading video 36/100: 94ETsdHWc5I
# Attempting download of 94ETsdHWc5I (attempt 1/3)
# Successfully downloaded 94ETsdHWc5I: 53139.6KB
# ✓ Successfully downloaded 94ETsdHWc5I
# Downloading video 37/100: Fr2MlpDw6kI
# Attempting download of Fr2MlpDw6kI (attempt 1/3)
# Successfully downloaded Fr2MlpDw6kI: 21939.3KB
# ✓ Successfully downloaded Fr2MlpDw6kI
# Downloading video 38/100: Fr2-zQAAqDg
# Attempting download of Fr2-zQAAqDg (attempt 1/3)
# Successfully downloaded Fr2-zQAAqDg: 12418.5KB
# ✓ Successfully downloaded Fr2-zQAAqDg
# Downloading video 39/100: FR33ODVkG4Q
# Attempting download of FR33ODVkG4Q (attempt 1/3)
# Successfully downloaded FR33ODVkG4Q: 22290.1KB
# ✓ Successfully downloaded FR33ODVkG4Q
# Downloading video 40/100: yGp198OfnjU
# Attempting download of yGp198OfnjU (attempt 1/3)
# Successfully downloaded yGp198OfnjU: 37653.2KB
# ✓ Successfully downloaded yGp198OfnjU
# Downloading video 41/100: VlfVUILsVVE
# Attempting download of VlfVUILsVVE (attempt 1/3)
# Successfully downloaded VlfVUILsVVE: 12674.0KB
# ✓ Successfully downloaded VlfVUILsVVE
# Downloading video 42/100: q0XJANEQw34
# Attempting download of q0XJANEQw34 (attempt 1/3)
# Successfully downloaded q0XJANEQw34: 43681.0KB
# ✓ Successfully downloaded q0XJANEQw34
# Downloading video 43/100: ygpBWTs9sgA
# Attempting download of ygpBWTs9sgA (attempt 1/3)
# Successfully downloaded ygpBWTs9sgA: 13464.9KB
# ✓ Successfully downloaded ygpBWTs9sgA
# Downloading video 44/100: t3SQTB8jtRk
# Attempting download of t3SQTB8jtRk (attempt 1/3)
# Successfully downloaded t3SQTB8jtRk: 17222.0KB
# ✓ Successfully downloaded t3SQTB8jtRk
# Downloading video 45/100: yGp_DQbqRRQ
# Attempting download of yGp_DQbqRRQ (attempt 1/3)
# Successfully downloaded yGp_DQbqRRQ: 6256.3KB
# ✓ Successfully downloaded yGp_DQbqRRQ
# Downloading video 46/100: mygaqDEv1jY
# Attempting download of mygaqDEv1jY (attempt 1/3)
# Successfully downloaded mygaqDEv1jY: 9344.9KB
# ✓ Successfully downloaded mygaqDEv1jY
# Downloading video 47/100: t3tA61scwf8
# Attempting download of t3tA61scwf8 (attempt 1/3)
# Successfully downloaded t3tA61scwf8: 9515.6KB
# ✓ Successfully downloaded t3tA61scwf8
# Downloading video 48/100: mYGdvelwdz0
# Attempting download of mYGdvelwdz0 (attempt 1/3)
# Error downloading mYGdvelwdz0: ERROR: [youtube] mYGdvelwdz0: Video unavailable
# ...
# Attempting download of mYGdvelwdz0 (attempt 2/3)
# Error downloading mYGdvelwdz0: ERROR: [youtube] mYGdvelwdz0: Video unavailable
# ...
# Attempting download of mYGdvelwdz0 (attempt 3/3)
# Error downloading mYGdvelwdz0: ERROR: [youtube] mYGdvelwdz0: Video unavailable
# ...
# Max retries reached for mYGdvelwdz0
# ✗ Failed to download mYGdvelwdz0
# Downloading video 49/100: T3TKGlRKPKc
# Attempting download of T3TKGlRKPKc (attempt 1/3)
# Successfully downloaded T3TKGlRKPKc: 6300.8KB
# ✓ Successfully downloaded T3TKGlRKPKc
# Downloading video 50/100: M_ygMvTjCpo
# Attempting download of M_ygMvTjCpo (attempt 1/3)
# Successfully downloaded M_ygMvTjCpo: 11666.4KB
# ✓ Successfully downloaded M_ygMvTjCpo
# Downloading video 51/100: SksCcc7hh18
# Attempting download of SksCcc7hh18 (attempt 1/3)
# Successfully downloaded SksCcc7hh18: 6252.5KB
# ✓ Successfully downloaded SksCcc7hh18
# Downloading video 52/100: piLb9prqpgA
# Attempting download of piLb9prqpgA (attempt 1/3)
# Successfully downloaded piLb9prqpgA: 56945.3KB
# ✓ Successfully downloaded piLb9prqpgA
# Downloading video 53/100: UyFYgeE32f0
# Attempting download of UyFYgeE32f0 (attempt 1/3)
# Successfully downloaded UyFYgeE32f0: 10559.7KB
# ✓ Successfully downloaded UyFYgeE32f0
# Downloading video 54/100: UyG0mWtcp6Y
# Attempting download of UyG0mWtcp6Y (attempt 1/3)
# Successfully downloaded UyG0mWtcp6Y: 3815.8KB
# ✓ Successfully downloaded UyG0mWtcp6Y
# Downloading video 55/100: xUiWw4GLSqk
# Attempting download of xUiWw4GLSqk (attempt 1/3)
# Successfully downloaded xUiWw4GLSqk: 18677.1KB
# ✓ Successfully downloaded xUiWw4GLSqk
# Downloading video 56/100: XuIYf9h6o2k
# Attempting download of XuIYf9h6o2k (attempt 1/3)
# Successfully downloaded XuIYf9h6o2k: 77451.7KB
# ✓ Successfully downloaded XuIYf9h6o2k
# Downloading video 57/100: xUIYXSpcAyM
# Attempting download of xUIYXSpcAyM (attempt 1/3)
# Successfully downloaded xUIYXSpcAyM: 4070.0KB
# ✓ Successfully downloaded xUIYXSpcAyM
# Downloading video 58/100: XUj2i-1R_Qk
# Attempting download of XUj2i-1R_Qk (attempt 1/3)
# Successfully downloaded XUj2i-1R_Qk: 42210.4KB
# ✓ Successfully downloaded XUj2i-1R_Qk
# Downloading video 59/100: P_iLiozRMzA
# Attempting download of P_iLiozRMzA (attempt 1/3)
# Error downloading P_iLiozRMzA: ERROR: [youtube] P_iLiozRMzA: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# ...
# Attempting download of P_iLiozRMzA (attempt 2/3)
# Error downloading P_iLiozRMzA: ERROR: [youtube] P_iLiozRMzA: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# ...
# Attempting download of P_iLiozRMzA (attempt 3/3)
# Error downloading P_iLiozRMzA: ERROR: [youtube] P_iLiozRMzA: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# ...
# Max retries reached for P_iLiozRMzA
# ✗ Failed to download P_iLiozRMzA
# Downloading video 60/100: UygPcBCFRrA
# Attempting download of UygPcBCFRrA (attempt 1/3)
# Successfully downloaded UygPcBCFRrA: 3483.7KB
# ✓ Successfully downloaded UygPcBCFRrA
# Downloading video 61/100: lDzkvV1Dg8M
# Attempting download of lDzkvV1Dg8M (attempt 1/3)
# Successfully downloaded lDzkvV1Dg8M: 17771.8KB
# ✓ Successfully downloaded lDzkvV1Dg8M
# Downloading video 62/100: Rixj7SNIpZE
# Attempting download of Rixj7SNIpZE (attempt 1/3)
# Successfully downloaded Rixj7SNIpZE: 107366.9KB
# ✓ Successfully downloaded Rixj7SNIpZE
# Downloading video 63/100: TWegHd8Sv2I
# Attempting download of TWegHd8Sv2I (attempt 1/3)
# Successfully downloaded TWegHd8Sv2I: 7304.1KB
# ✓ Successfully downloaded TWegHd8Sv2I
# Downloading video 64/100: lDZUjk5e3dc
# Attempting download of lDZUjk5e3dc (attempt 1/3)
# Successfully downloaded lDZUjk5e3dc: 6573.2KB
# ✓ Successfully downloaded lDZUjk5e3dc
# Downloading video 65/100: OG_SrWwKXI4
# Attempting download of OG_SrWwKXI4 (attempt 1/3)
# Successfully downloaded OG_SrWwKXI4: 28539.0KB
# ✓ Successfully downloaded OG_SrWwKXI4
# Downloading video 66/100: TWeKSzIwSeA
# Attempting download of TWeKSzIwSeA (attempt 1/3)
# Error downloading TWeKSzIwSeA: ERROR: [youtube] TWeKSzIwSeA: Video unavailable
# ...
# Attempting download of TWeKSzIwSeA (attempt 2/3)
# Error downloading TWeKSzIwSeA: ERROR: [youtube] TWeKSzIwSeA: Video unavailable
# ...
# Attempting download of TWeKSzIwSeA (attempt 3/3)
# Error downloading TWeKSzIwSeA: ERROR: [youtube] TWeKSzIwSeA: Video unavailable
# ...
# Max retries reached for TWeKSzIwSeA
# ✗ Failed to download TWeKSzIwSeA
# Downloading video 67/100: L-DZ-YhG27k
# Attempting download of L-DZ-YhG27k (attempt 1/3)
# Error downloading L-DZ-YhG27k: ERROR: [youtube] L-DZ-YhG27k: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of L-DZ-YhG27k (attempt 2/3)
# Error downloading L-DZ-YhG27k: ERROR: [youtube] L-DZ-YhG27k: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of L-DZ-YhG27k (attempt 3/3)
# Error downloading L-DZ-YhG27k: ERROR: [youtube] L-DZ-YhG27k: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Max retries reached for L-DZ-YhG27k
# ✗ Failed to download L-DZ-YhG27k
# Downloading video 68/100: jXiLKJQdzoU
# Attempting download of jXiLKJQdzoU (attempt 1/3)
# Error downloading jXiLKJQdzoU: ERROR: [youtube] jXiLKJQdzoU: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of jXiLKJQdzoU (attempt 2/3)
# Error downloading jXiLKJQdzoU: ERROR: [youtube] jXiLKJQdzoU: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of jXiLKJQdzoU (attempt 3/3)
# Error downloading jXiLKJQdzoU: ERROR: [youtube] jXiLKJQdzoU: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Max retries reached for jXiLKJQdzoU
# ✗ Failed to download jXiLKJQdzoU
# Downloading video 69/100: oGSuPfHk4qc
# Attempting download of oGSuPfHk4qc (attempt 1/3)
# Successfully downloaded oGSuPfHk4qc: 12284.9KB
# ✓ Successfully downloaded oGSuPfHk4qc
# Downloading video 70/100: JXIo5GsmUP8
# Attempting download of JXIo5GsmUP8 (attempt 1/3)
# Successfully downloaded JXIo5GsmUP8: 98331.9KB
# ✓ Successfully downloaded JXIo5GsmUP8
# Downloading video 71/100: le-0B39__8Y
# Attempting download of le-0B39__8Y (attempt 1/3)
# Successfully downloaded le-0B39__8Y: 18371.8KB
# ✓ Successfully downloaded le-0B39__8Y
# Downloading video 72/100: oGT8PjhEj9k
# Attempting download of oGT8PjhEj9k (attempt 1/3)
# Successfully downloaded oGT8PjhEj9k: 14877.4KB
# ✓ Successfully downloaded oGT8PjhEj9k
# Downloading video 73/100: tWeqbL5Sv38
# Attempting download of tWeqbL5Sv38 (attempt 1/3)
# Error downloading tWeqbL5Sv38: ERROR: [youtube] tWeqbL5Sv38: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of tWeqbL5Sv38 (attempt 2/3)
# Error downloading tWeqbL5Sv38: ERROR: [youtube] tWeqbL5Sv38: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of tWeqbL5Sv38 (attempt 3/3)
# Error downloading tWeqbL5Sv38: ERROR: [youtube] tWeqbL5Sv38: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Max retries reached for tWeqbL5Sv38
# ✗ Failed to download tWeqbL5Sv38
# Downloading video 74/100: JxISDimjMt0
# Attempting download of JxISDimjMt0 (attempt 1/3)
# Successfully downloaded JxISDimjMt0: 25927.4KB
# ✓ Successfully downloaded JxISDimjMt0
# Downloading video 75/100: whJBPTbLhwc
# Attempting download of whJBPTbLhwc (attempt 1/3)
# Error downloading whJBPTbLhwc: ERROR: [youtube] whJBPTbLhwc: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of whJBPTbLhwc (attempt 2/3)
# Error downloading whJBPTbLhwc: ERROR: [youtube] whJBPTbLhwc: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of whJBPTbLhwc (attempt 3/3)
# Error downloading whJBPTbLhwc: ERROR: [youtube] whJBPTbLhwc: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Max retries reached for whJBPTbLhwc
# ✗ Failed to download whJBPTbLhwc
# Downloading video 76/100: ZbWY3ojVPEA
# Attempting download of ZbWY3ojVPEA (attempt 1/3)
# Error downloading ZbWY3ojVPEA: ERROR: [youtube] ZbWY3ojVPEA: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# ...
# Attempting download of ZbWY3ojVPEA (attempt 2/3)
# Error downloading ZbWY3ojVPEA: ERROR: [youtube] ZbWY3ojVPEA: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# ...
# Attempting download of ZbWY3ojVPEA (attempt 3/3)
# Error downloading ZbWY3ojVPEA: ERROR: [youtube] ZbWY3ojVPEA: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# ...
# Max retries reached for ZbWY3ojVPEA
# ✗ Failed to download ZbWY3ojVPEA
# Downloading video 77/100: zbWyFFrSRdU
# Attempting download of zbWyFFrSRdU (attempt 1/3)
# Error downloading zbWyFFrSRdU: ERROR: [youtube] zbWyFFrSRdU: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of zbWyFFrSRdU (attempt 2/3)
# Error downloading zbWyFFrSRdU: ERROR: [youtube] zbWyFFrSRdU: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of zbWyFFrSRdU (attempt 3/3)
# Error downloading zbWyFFrSRdU: ERROR: [youtube] zbWyFFrSRdU: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Max retries reached for zbWyFFrSRdU
# ✗ Failed to download zbWyFFrSRdU
# Downloading video 78/100: wHjn2BrVUe0
# Attempting download of wHjn2BrVUe0 (attempt 1/3)
# Successfully downloaded wHjn2BrVUe0: 31304.7KB
# ✓ Successfully downloaded wHjn2BrVUe0
# Downloading video 79/100: wHjXFrzGW3g
# Attempting download of wHjXFrzGW3g (attempt 1/3)
# Successfully downloaded wHjXFrzGW3g: 4222.7KB
# ✓ Successfully downloaded wHjXFrzGW3g
# Downloading video 80/100: zBxNDgmFEOY
# Attempting download of zBxNDgmFEOY (attempt 1/3)
# Successfully downloaded zBxNDgmFEOY: 3028.3KB
# ✓ Successfully downloaded zBxNDgmFEOY
# Downloading video 81/100: WHkEvIsvHR4
# Attempting download of WHkEvIsvHR4 (attempt 1/3)
# Successfully downloaded WHkEvIsvHR4: 9247.0KB
# ✓ Successfully downloaded WHkEvIsvHR4
# Downloading video 82/100: WhKfMc0Jv6c
# Attempting download of WhKfMc0Jv6c (attempt 1/3)
# Successfully downloaded WhKfMc0Jv6c: 30612.2KB
# ✓ Successfully downloaded WhKfMc0Jv6c
# Downloading video 83/100: -whkFO7P0Bs
# Attempting download of -whkFO7P0Bs (attempt 1/3)
# Error downloading -whkFO7P0Bs: ERROR: [youtube] -whkFO7P0Bs: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of -whkFO7P0Bs (attempt 2/3)
# Error downloading -whkFO7P0Bs: ERROR: [youtube] -whkFO7P0Bs: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of -whkFO7P0Bs (attempt 3/3)
# Error downloading -whkFO7P0Bs: ERROR: [youtube] -whkFO7P0Bs: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Max retries reached for -whkFO7P0Bs
# ✗ Failed to download -whkFO7P0Bs
# Downloading video 84/100: wHKqzcemXE4
# Attempting download of wHKqzcemXE4 (attempt 1/3)
# Successfully downloaded wHKqzcemXE4: 10600.0KB
# ✓ Successfully downloaded wHKqzcemXE4
# Downloading video 85/100: CrAbMqNqz8I
# Attempting download of CrAbMqNqz8I (attempt 1/3)
# Successfully downloaded CrAbMqNqz8I: 79377.5KB
# ✓ Successfully downloaded CrAbMqNqz8I
# Downloading video 86/100: gRnAwURu4c0
# Attempting download of gRnAwURu4c0 (attempt 1/3)
# Error downloading gRnAwURu4c0: ERROR: [youtube] gRnAwURu4c0: Video unavailable. This video is no longer available because the uploader has closed their YouTube account.
# ...
# Attempting download of gRnAwURu4c0 (attempt 2/3)
# Error downloading gRnAwURu4c0: ERROR: [youtube] gRnAwURu4c0: Video unavailable. This video is no longer available because the uploader has closed their YouTube account.
# ...
# Attempting download of gRnAwURu4c0 (attempt 3/3)
# Error downloading gRnAwURu4c0: ERROR: [youtube] gRnAwURu4c0: Video unavailable. This video is no longer available because the uploader has closed their YouTube account.
# ...
# Max retries reached for gRnAwURu4c0
# ✗ Failed to download gRnAwURu4c0
# Downloading video 87/100: GRNbW_C0GZM
# Attempting download of GRNbW_C0GZM (attempt 1/3)
# Successfully downloaded GRNbW_C0GZM: 13615.4KB
# ✓ Successfully downloaded GRNbW_C0GZM
# Downloading video 88/100: CRAfCCV604A
# Attempting download of CRAfCCV604A (attempt 1/3)
# Successfully downloaded CRAfCCV604A: 31163.1KB
# ✓ Successfully downloaded CRAfCCV604A
# Downloading video 89/100: 589yOyF0X20
# Attempting download of 589yOyF0X20 (attempt 1/3)
# Successfully downloaded 589yOyF0X20: 26908.5KB
# ✓ Successfully downloaded 589yOyF0X20
# Downloading video 90/100: I3iWvy1LOCA
# Attempting download of I3iWvy1LOCA (attempt 1/3)
# Successfully downloaded I3iWvy1LOCA: 44667.7KB
# ✓ Successfully downloaded I3iWvy1LOCA
# Downloading video 91/100: IdsVdNQ6Dts
# Attempting download of IdsVdNQ6Dts (attempt 1/3)
# Successfully downloaded IdsVdNQ6Dts: 22109.0KB
# ✓ Successfully downloaded IdsVdNQ6Dts
# Downloading video 92/100: gXceF_kx2h0
# Attempting download of gXceF_kx2h0 (attempt 1/3)
# Successfully downloaded gXceF_kx2h0: 14219.8KB
# ✓ Successfully downloaded gXceF_kx2h0
# Downloading video 93/100: 5kKne_H-nGo
# Attempting download of 5kKne_H-nGo (attempt 1/3)
# Successfully downloaded 5kKne_H-nGo: 2139.1KB
# ✓ Successfully downloaded 5kKne_H-nGo
# Downloading video 94/100: idswOkT4-48
# Attempting download of idswOkT4-48 (attempt 1/3)
# Successfully downloaded idswOkT4-48: 16393.0KB
# ✓ Successfully downloaded idswOkT4-48
# Downloading video 95/100: gXcibs8qkw8
# Attempting download of gXcibs8qkw8 (attempt 1/3)
# Successfully downloaded gXcibs8qkw8: 7461.9KB
# ✓ Successfully downloaded gXcibs8qkw8
# Downloading video 96/100: GxCu1xdMPtg
# Attempting download of GxCu1xdMPtg (attempt 1/3)
# Successfully downloaded GxCu1xdMPtg: 7008.5KB
# ✓ Successfully downloaded GxCu1xdMPtg
# Downloading video 97/100: aRUsvr7Fivk
# Attempting download of aRUsvr7Fivk (attempt 1/3)
# Successfully downloaded aRUsvr7Fivk: 16537.6KB
# ✓ Successfully downloaded aRUsvr7Fivk
# Downloading video 98/100: arUt4khitoY
# Attempting download of arUt4khitoY (attempt 1/3)
# Successfully downloaded arUt4khitoY: 15343.0KB
# ✓ Successfully downloaded arUt4khitoY
# Downloading video 99/100: GXd3V0I3v0E
# Attempting download of GXd3V0I3v0E (attempt 1/3)
# Successfully downloaded GXd3V0I3v0E: 17783.3KB
# ✓ Successfully downloaded GXd3V0I3v0E
# Downloading video 100/100: 0qJKm2p2NSg
# Attempting download of 0qJKm2p2NSg (attempt 1/3)
# Successfully downloaded 0qJKm2p2NSg: 14146.1KB
# ✓ Successfully downloaded 0qJKm2p2NSg
# Downloaded 84 videos successfully
# Generating embeddings for 84 videos using Spark...
# Using 4 partitions for 84 videos
# Starting parallel processing with 4 partitions
#
# Processed 84 videos, got 84 successful results
# Processing speed: 0.39 successful videos/second
# Batch 22: Processed 84/100 videos in 1261.63s
# Aggregated 2520 embeddings in 0.00s
# Adding 2520 new embeddings to index
# Saving local index with 17400 total embeddings
# Index operations took 0.15s
# ✓ Checkpoint saved (batch 21, 17400 embeddings)
# Syncing index and metadata to Drive...
# Synced /content/checkpoint.pkl to /content/drive/MyDrive/video_embeddings_project/checkpoint.pkl
# Synced /content/metadata.pkl to /content/drive/MyDrive/video_embeddings_project/metadata.pkl
# Synced /content/video_embeddings.index to /content/drive/MyDrive/video_embeddings_project/video_embeddings.index
# Sync to Drive completed in 0.37s
# Checkpoint saved at batch 22
#
# Overall progress: 800/6000 videos (13.3%)
# Elapsed time: 0.35 hours
# Estimated remaining time: 0.00 hours
# ============================================================
#
#
# ============================================================
# PROCESSING BATCH 23/60
# ============================================================
# Videos in this batch: 100
# First few videos: ['eNa3XRJNdGI', '0QJM-sn3Huo', 'enA6xo-3a7Q', '0QK6l3bjxcU', '0QL8g0ums9c']
# RAM: 9.7/12.7 GB (79.0%)
# GPU: 448.0/15360.0 MB (2.9%)
# Batch 23: Starting processing at 19:37:44
# Downloading 100 videos sequentially (no parallelism)...
# Downloading video 1/100: eNa3XRJNdGI
# Attempting download of eNa3XRJNdGI (attempt 1/3)
# Successfully downloaded eNa3XRJNdGI: 9674.8KB
# ✓ Successfully downloaded eNa3XRJNdGI
# Downloading video 2/100: 0QJM-sn3Huo
# Attempting download of 0QJM-sn3Huo (attempt 1/3)
# Successfully downloaded 0QJM-sn3Huo: 3155.9KB
# ✓ Successfully downloaded 0QJM-sn3Huo
# Downloading video 3/100: enA6xo-3a7Q
# Attempting download of enA6xo-3a7Q (attempt 1/3)
# Successfully downloaded enA6xo-3a7Q: 11181.2KB
# ✓ Successfully downloaded enA6xo-3a7Q
# Downloading video 4/100: 0QK6l3bjxcU
# Attempting download of 0QK6l3bjxcU (attempt 1/3)
# Successfully downloaded 0QK6l3bjxcU: 11298.3KB
# ✓ Successfully downloaded 0QK6l3bjxcU
# Downloading video 5/100: 0QL8g0ums9c
# Attempting download of 0QL8g0ums9c (attempt 1/3)
# Successfully downloaded 0QL8g0ums9c: 40806.1KB
# ✓ Successfully downloaded 0QL8g0ums9c
# Downloading video 6/100: 0QlmqU4ShC0
# Attempting download of 0QlmqU4ShC0 (attempt 1/3)
# Successfully downloaded 0QlmqU4ShC0: 9543.0KB
# ✓ Successfully downloaded 0QlmqU4ShC0
# Downloading video 7/100: 0qMAnKZcKlo
# Attempting download of 0qMAnKZcKlo (attempt 1/3)
# Successfully downloaded 0qMAnKZcKlo: 24391.2KB
# ✓ Successfully downloaded 0qMAnKZcKlo
# Downloading video 8/100: 1ywhJSwvs8c
# Attempting download of 1ywhJSwvs8c (attempt 1/3)
# Successfully downloaded 1ywhJSwvs8c: 8160.2KB
# ✓ Successfully downloaded 1ywhJSwvs8c
# Downloading video 9/100: 802j8J_zn8I
# Attempting download of 802j8J_zn8I (attempt 1/3)
# Successfully downloaded 802j8J_zn8I: 13305.0KB
# ✓ Successfully downloaded 802j8J_zn8I
# Downloading video 10/100: 1ywJhQxEaMU
# Attempting download of 1ywJhQxEaMU (attempt 1/3)
# Successfully downloaded 1ywJhQxEaMU: 13588.5KB
# ✓ Successfully downloaded 1ywJhQxEaMU
# Downloading video 11/100: 1yWpHwqZqnA
# Attempting download of 1yWpHwqZqnA (attempt 1/3)
# Successfully downloaded 1yWpHwqZqnA: 14290.9KB
# ✓ Successfully downloaded 1yWpHwqZqnA
# Downloading video 12/100: FASnEvrcfYQ
# Attempting download of FASnEvrcfYQ (attempt 1/3)
# Successfully downloaded FASnEvrcfYQ: 85718.9KB
# ✓ Successfully downloaded FASnEvrcfYQ
# Downloading video 13/100: 1YX4Cad30mE
# Attempting download of 1YX4Cad30mE (attempt 1/3)
# Error downloading 1YX4Cad30mE: ERROR: [youtube] 1YX4Cad30mE: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of 1YX4Cad30mE (attempt 2/3)
# Error downloading 1YX4Cad30mE: ERROR: [youtube] 1YX4Cad30mE: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of 1YX4Cad30mE (attempt 3/3)
# Error downloading 1YX4Cad30mE: ERROR: [youtube] 1YX4Cad30mE: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Max retries reached for 1YX4Cad30mE
# ✗ Failed to download 1YX4Cad30mE
# Downloading video 14/100: 1yXIIzxS6co
# Attempting download of 1yXIIzxS6co (attempt 1/3)
# Successfully downloaded 1yXIIzxS6co: 19985.0KB
# ✓ Successfully downloaded 1yXIIzxS6co
# Downloading video 15/100: 808HUaxP538
# Attempting download of 808HUaxP538 (attempt 1/3)
# Successfully downloaded 808HUaxP538: 12724.3KB
# ✓ Successfully downloaded 808HUaxP538
# Downloading video 16/100: fasvhVtXrzY
# Attempting download of fasvhVtXrzY (attempt 1/3)
# Successfully downloaded fasvhVtXrzY: 22289.2KB
# ✓ Successfully downloaded fasvhVtXrzY
# Downloading video 17/100: 809TZnjruKI
# Attempting download of 809TZnjruKI (attempt 1/3)
# Successfully downloaded 809TZnjruKI: 53378.4KB
# ✓ Successfully downloaded 809TZnjruKI
# Downloading video 18/100: 80A7tz21Pdw
# Attempting download of 80A7tz21Pdw (attempt 1/3)
# Successfully downloaded 80A7tz21Pdw: 11313.3KB
# ✓ Successfully downloaded 80A7tz21Pdw
# Downloading video 19/100: 80AlVsSwbNk
# Attempting download of 80AlVsSwbNk (attempt 1/3)
# Successfully downloaded 80AlVsSwbNk: 59497.9KB
# ✓ Successfully downloaded 80AlVsSwbNk
# Downloading video 20/100: JFCesd3hMvk
# Attempting download of JFCesd3hMvk (attempt 1/3)
# Error downloading JFCesd3hMvk: ERROR: [youtube] JFCesd3hMvk: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of JFCesd3hMvk (attempt 2/3)
# Error downloading JFCesd3hMvk: ERROR: [youtube] JFCesd3hMvk: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of JFCesd3hMvk (attempt 3/3)
# Error downloading JFCesd3hMvk: ERROR: [youtube] JFCesd3hMvk: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Max retries reached for JFCesd3hMvk
# ✗ Failed to download JFCesd3hMvk
# Downloading video 21/100: qvn8vWrFxU8
# Attempting download of qvn8vWrFxU8 (attempt 1/3)
# Successfully downloaded qvn8vWrFxU8: 13594.6KB
# ✓ Successfully downloaded qvn8vWrFxU8
# Downloading video 22/100: dVKfgg-8fMA
# Attempting download of dVKfgg-8fMA (attempt 1/3)
# Successfully downloaded dVKfgg-8fMA: 10367.6KB
# ✓ Successfully downloaded dVKfgg-8fMA
# Downloading video 23/100: jFcFEJ4Jiqs
# Attempting download of jFcFEJ4Jiqs (attempt 1/3)
# Successfully downloaded jFcFEJ4Jiqs: 48844.9KB
# ✓ Successfully downloaded jFcFEJ4Jiqs
# Downloading video 24/100: kQob8IwUelY
# Attempting download of kQob8IwUelY (attempt 1/3)
# Successfully downloaded kQob8IwUelY: 94105.4KB
# ✓ Successfully downloaded kQob8IwUelY
# Downloading video 25/100: dVkNeNLxafw
# Attempting download of dVkNeNLxafw (attempt 1/3)
# Successfully downloaded dVkNeNLxafw: 8882.8KB
# ✓ Successfully downloaded dVkNeNLxafw
# Downloading video 26/100: kQOcAHuI65M
# Attempting download of kQOcAHuI65M (attempt 1/3)
# Successfully downloaded kQOcAHuI65M: 26742.2KB
# ✓ Successfully downloaded kQOcAHuI65M
# Downloading video 27/100: -dvKrPY2LWs
# Attempting download of -dvKrPY2LWs (attempt 1/3)
# Successfully downloaded -dvKrPY2LWs: 5315.6KB
# ✓ Successfully downloaded -dvKrPY2LWs
# Downloading video 28/100: DvKYAU2wrnI
# Attempting download of DvKYAU2wrnI (attempt 1/3)
# Error downloading DvKYAU2wrnI: ERROR: [youtube] DvKYAU2wrnI: Video unavailable
# ...
# Attempting download of DvKYAU2wrnI (attempt 2/3)
# Error downloading DvKYAU2wrnI: ERROR: [youtube] DvKYAU2wrnI: Video unavailable
# ...
# Attempting download of DvKYAU2wrnI (attempt 3/3)
# Error downloading DvKYAU2wrnI: ERROR: [youtube] DvKYAU2wrnI: Video unavailable
# ...
# Max retries reached for DvKYAU2wrnI
# ✗ Failed to download DvKYAU2wrnI
# Downloading video 29/100: JFcp-ZXEwMU
# Attempting download of JFcp-ZXEwMU (attempt 1/3)
# Successfully downloaded JFcp-ZXEwMU: 52624.8KB
# ✓ Successfully downloaded JFcp-ZXEwMU
# Downloading video 30/100: DvL7kCRTKuE
# Attempting download of DvL7kCRTKuE (attempt 1/3)
# Successfully downloaded DvL7kCRTKuE: 23335.7KB
# ✓ Successfully downloaded DvL7kCRTKuE
# Downloading video 31/100: R3AIhq7qwgA
# Attempting download of R3AIhq7qwgA (attempt 1/3)
# Successfully downloaded R3AIhq7qwgA: 21978.7KB
# ✓ Successfully downloaded R3AIhq7qwgA
# Downloading video 32/100: r3Akwa4laik
# Attempting download of r3Akwa4laik (attempt 1/3)
# Successfully downloaded r3Akwa4laik: 41349.6KB
# ✓ Successfully downloaded r3Akwa4laik
# Downloading video 33/100: nZKeseqwaL8
# Attempting download of nZKeseqwaL8 (attempt 1/3)
# Successfully downloaded nZKeseqwaL8: 14421.5KB
# ✓ Successfully downloaded nZKeseqwaL8
# Downloading video 34/100: NzKgM3XJdoA
# Attempting download of NzKgM3XJdoA (attempt 1/3)
# Successfully downloaded NzKgM3XJdoA: 20891.2KB
# ✓ Successfully downloaded NzKgM3XJdoA
# Downloading video 35/100: jLdlY7RFTf8
# Attempting download of jLdlY7RFTf8 (attempt 1/3)
# Successfully downloaded jLdlY7RFTf8: 22188.0KB
# ✓ Successfully downloaded jLdlY7RFTf8
# Downloading video 36/100: e3bidIxIsao
# Attempting download of e3bidIxIsao (attempt 1/3)
# Successfully downloaded e3bidIxIsao: 19491.7KB
# ✓ Successfully downloaded e3bidIxIsao
# Downloading video 37/100: KwmiAmly2Fo
# Attempting download of KwmiAmly2Fo (attempt 1/3)
# Successfully downloaded KwmiAmly2Fo: 14363.0KB
# ✓ Successfully downloaded KwmiAmly2Fo
# Downloading video 38/100: Nz_KhxWdBcI
# Attempting download of Nz_KhxWdBcI (attempt 1/3)
# Successfully downloaded Nz_KhxWdBcI: 28360.4KB
# ✓ Successfully downloaded Nz_KhxWdBcI
# Downloading video 39/100: jlDpoiJAudI
# Attempting download of jlDpoiJAudI (attempt 1/3)
# Successfully downloaded jlDpoiJAudI: 35403.3KB
# ✓ Successfully downloaded jlDpoiJAudI
# Downloading video 40/100: KWmjbm05h60
# Attempting download of KWmjbm05h60 (attempt 1/3)
# Error downloading KWmjbm05h60: ERROR: [youtube] KWmjbm05h60: Video unavailable
# ...
# Attempting download of KWmjbm05h60 (attempt 2/3)
# Error downloading KWmjbm05h60: ERROR: [youtube] KWmjbm05h60: Video unavailable
# ...
# Attempting download of KWmjbm05h60 (attempt 3/3)
# Error downloading KWmjbm05h60: ERROR: [youtube] KWmjbm05h60: Video unavailable
# ...
# Max retries reached for KWmjbm05h60
# ✗ Failed to download KWmjbm05h60
# Downloading video 41/100: v8GiFCyEc0I
# Attempting download of v8GiFCyEc0I (attempt 1/3)
# Successfully downloaded v8GiFCyEc0I: 24183.2KB
# ✓ Successfully downloaded v8GiFCyEc0I
# Downloading video 42/100: V8gLLLCC-pM
# Attempting download of V8gLLLCC-pM (attempt 1/3)
# Error downloading V8gLLLCC-pM: ERROR: [youtube] V8gLLLCC-pM: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of V8gLLLCC-pM (attempt 2/3)
# Error downloading V8gLLLCC-pM: ERROR: [youtube] V8gLLLCC-pM: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of V8gLLLCC-pM (attempt 3/3)
# Error downloading V8gLLLCC-pM: ERROR: [youtube] V8gLLLCC-pM: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Max retries reached for V8gLLLCC-pM
# ✗ Failed to download V8gLLLCC-pM
# Downloading video 43/100: pOKy7X_I5IE
# Attempting download of pOKy7X_I5IE (attempt 1/3)
# Successfully downloaded pOKy7X_I5IE: 25661.2KB
# ✓ Successfully downloaded pOKy7X_I5IE
# Downloading video 44/100: pol6OD08RAE
# Attempting download of pol6OD08RAE (attempt 1/3)
# Successfully downloaded pol6OD08RAE: 5116.8KB
# ✓ Successfully downloaded pol6OD08RAE
# Downloading video 45/100: V8GXL7qTHmw
# Attempting download of V8GXL7qTHmw (attempt 1/3)
# Successfully downloaded V8GXL7qTHmw: 44342.3KB
# ✓ Successfully downloaded V8GXL7qTHmw
# Downloading video 46/100: y0sbauJBXxQ
# Attempting download of y0sbauJBXxQ (attempt 1/3)
# Successfully downloaded y0sbauJBXxQ: 13189.8KB
# ✓ Successfully downloaded y0sbauJBXxQ
# Downloading video 47/100: y0SitjvY2C0
# Attempting download of y0SitjvY2C0 (attempt 1/3)
# Successfully downloaded y0SitjvY2C0: 18693.5KB
# ✓ Successfully downloaded y0SitjvY2C0
# Downloading video 48/100: POlea0r0-mg
# Attempting download of POlea0r0-mg (attempt 1/3)
# Successfully downloaded POlea0r0-mg: 21998.0KB
# ✓ Successfully downloaded POlea0r0-mg
# Downloading video 49/100: PO_LGJ-176E
# Attempting download of PO_LGJ-176E (attempt 1/3)
# Successfully downloaded PO_LGJ-176E: 38420.5KB
# ✓ Successfully downloaded PO_LGJ-176E
# Downloading video 50/100: -V8H8J5YbRI
# Attempting download of -V8H8J5YbRI (attempt 1/3)
# Successfully downloaded -V8H8J5YbRI: 6915.4KB
# ✓ Successfully downloaded -V8H8J5YbRI
# Downloading video 51/100: v8HFdi9oJsw
# Attempting download of v8HFdi9oJsw (attempt 1/3)
# Successfully downloaded v8HFdi9oJsw: 16034.0KB
# ✓ Successfully downloaded v8HFdi9oJsw
# Downloading video 52/100: -C8vZ2xs-aQ
# Attempting download of -C8vZ2xs-aQ (attempt 1/3)
# Successfully downloaded -C8vZ2xs-aQ: 32221.7KB
# ✓ Successfully downloaded -C8vZ2xs-aQ
# Downloading video 53/100: C8vzrNrnU9g
# Attempting download of C8vzrNrnU9g (attempt 1/3)
# Successfully downloaded C8vzrNrnU9g: 5883.0KB
# ✓ Successfully downloaded C8vzrNrnU9g
# Downloading video 54/100: A0Bt820HeHE
# Attempting download of A0Bt820HeHE (attempt 1/3)
# Successfully downloaded A0Bt820HeHE: 14636.2KB
# ✓ Successfully downloaded A0Bt820HeHE
# Downloading video 55/100: Hi9l0oA5SAI
# Attempting download of Hi9l0oA5SAI (attempt 1/3)
# Successfully downloaded Hi9l0oA5SAI: 21626.9KB
# ✓ Successfully downloaded Hi9l0oA5SAI
# Downloading video 56/100: GaQxAxqtXt4
# Attempting download of GaQxAxqtXt4 (attempt 1/3)
# Successfully downloaded GaQxAxqtXt4: 44632.0KB
# ✓ Successfully downloaded GaQxAxqtXt4
# Downloading video 57/100: Hi9oY8ifLTA
# Attempting download of Hi9oY8ifLTA (attempt 1/3)
# Successfully downloaded Hi9oY8ifLTA: 35364.1KB
# ✓ Successfully downloaded Hi9oY8ifLTA
# Downloading video 58/100: G-aQzoHqM80
# Attempting download of G-aQzoHqM80 (attempt 1/3)
# Successfully downloaded G-aQzoHqM80: 33894.3KB
# ✓ Successfully downloaded G-aQzoHqM80
# Downloading video 59/100: hi9s4Oph4QQ
# Attempting download of hi9s4Oph4QQ (attempt 1/3)
# Successfully downloaded hi9s4Oph4QQ: 20692.8KB
# ✓ Successfully downloaded hi9s4Oph4QQ
# Downloading video 60/100: gar-4qh94fY
# Attempting download of gar-4qh94fY (attempt 1/3)
# Successfully downloaded gar-4qh94fY: 19181.7KB
# ✓ Successfully downloaded gar-4qh94fY
# Downloading video 61/100: a0ciEU0gBiQ
# Attempting download of a0ciEU0gBiQ (attempt 1/3)
# Successfully downloaded a0ciEU0gBiQ: 29343.7KB
# ✓ Successfully downloaded a0ciEU0gBiQ
# Downloading video 62/100: c8woMoExRjU
# Attempting download of c8woMoExRjU (attempt 1/3)
# Successfully downloaded c8woMoExRjU: 42414.5KB
# ✓ Successfully downloaded c8woMoExRjU
# Downloading video 63/100: HI9vQrdK51c
# Attempting download of HI9vQrdK51c (attempt 1/3)
# Successfully downloaded HI9vQrdK51c: 10471.8KB
# ✓ Successfully downloaded HI9vQrdK51c
# Downloading video 64/100: 41D5XXqRLrc
# Attempting download of 41D5XXqRLrc (attempt 1/3)
# Successfully downloaded 41D5XXqRLrc: 56430.5KB
# ✓ Successfully downloaded 41D5XXqRLrc
# Downloading video 65/100: V-FGBMXkvqs
# Attempting download of V-FGBMXkvqs (attempt 1/3)
# Successfully downloaded V-FGBMXkvqs: 16306.2KB
# ✓ Successfully downloaded V-FGBMXkvqs
# Downloading video 66/100: YBdtI6n9ZKI
# Attempting download of YBdtI6n9ZKI (attempt 1/3)
# Successfully downloaded YBdtI6n9ZKI: 2767.2KB
# ✓ Successfully downloaded YBdtI6n9ZKI
# Downloading video 67/100: yBdVAIhb0Jw
# Attempting download of yBdVAIhb0Jw (attempt 1/3)
# Successfully downloaded yBdVAIhb0Jw: 5026.7KB
# ✓ Successfully downloaded yBdVAIhb0Jw
# Downloading video 68/100: pUFldybckzk
# Attempting download of pUFldybckzk (attempt 1/3)
# Error downloading pUFldybckzk: ERROR: [youtube] pUFldybckzk: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of pUFldybckzk (attempt 2/3)
# Error downloading pUFldybckzk: ERROR: [youtube] pUFldybckzk: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Attempting download of pUFldybckzk (attempt 3/3)
# Error downloading pUFldybckzk: ERROR: [youtube] pUFldybckzk: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/...
# Max retries reached for pUFldybckzk
# ✗ Failed to download pUFldybckzk
# Downloading video 69/100: mS0_CfHNeYQ
# Attempting download of mS0_CfHNeYQ (attempt 1/3)
# Successfully downloaded mS0_CfHNeYQ: 15411.0KB
# ✓ Successfully downloaded mS0_CfHNeYQ
# Downloading video 70/100: vfGjFAE_UPk
# Attempting download of vfGjFAE_UPk (attempt 1/3)
# Successfully downloaded vfGjFAE_UPk: 30918.3KB
# ✓ Successfully downloaded vfGjFAE_UPk
# Downloading video 71/100: yBE2-OEQUQc
# Attempting download of yBE2-OEQUQc (attempt 1/3)
# Successfully downloaded yBE2-OEQUQc: 16575.1KB
# ✓ Successfully downloaded yBE2-OEQUQc
# Downloading video 72/100: VFgLtWL2sRY
# Attempting download of VFgLtWL2sRY (attempt 1/3)
# Error downloading VFgLtWL2sRY: ERROR: [youtube] VFgLtWL2sRY: Video unavailable
# ...
# Attempting download of VFgLtWL2sRY (attempt 2/3)
# Error downloading VFgLtWL2sRY: ERROR: [youtube] VFgLtWL2sRY: Video unavailable
# ...
# Attempting download of VFgLtWL2sRY (attempt 3/3)
# Error downloading VFgLtWL2sRY: ERROR: [youtube] VFgLtWL2sRY: Video unavailable
# ...
# Max retries reached for VFgLtWL2sRY
# ✗ Failed to download VFgLtWL2sRY
# Downloading video 73/100: VFgN_doWFP0
# Attempting download of VFgN_doWFP0 (attempt 1/3)
# Successfully downloaded VFgN_doWFP0: 7664.7KB
# ✓ Successfully downloaded VFgN_doWFP0
# Downloading video 74/100: pug34iIXYyg
# Attempting download of pug34iIXYyg (attempt 1/3)
# ...
# Attempting download of rTFS98ls8FQ (attempt 3/3)
# Error downloading rTFS98ls8FQ: ERROR: [youtube] rTFS98ls8FQ: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Max retries reached for rTFS98ls8FQ
# ✗ Failed to download rTFS98ls8FQ
# Downloading video 100/100: RTFSzXnlx4E
# Attempting download of RTFSzXnlx4E (attempt 1/3)
# Error downloading RTFSzXnlx4E: ERROR: [youtube] RTFSzXnlx4E: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of RTFSzXnlx4E (attempt 2/3)
# Error downloading RTFSzXnlx4E: ERROR: [youtube] RTFSzXnlx4E: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of RTFSzXnlx4E (attempt 3/3)
# Error downloading RTFSzXnlx4E: ERROR: [youtube] RTFSzXnlx4E: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Max retries reached for RTFSzXnlx4E
# ✗ Failed to download RTFSzXnlx4E
# Downloaded 41 videos successfully
# Generating embeddings for 41 videos using Spark...
# Using 4 partitions for 41 videos
# Starting parallel processing with 4 partitions
#
# Processed 41 videos, got 41 successful results
# Processing speed: 0.26 successful videos/second
# Batch 24: Processed 41/100 videos in 1353.96s
# Aggregated 1230 embeddings in 0.00s
# Adding 1230 new embeddings to index
# Saving local index with 21300 total embeddings
# Index operations took 0.19s
# ✓ Checkpoint saved (batch 23, 21300 embeddings)
# Syncing index and metadata to Drive...
# Synced /content/checkpoint.pkl to /content/drive/MyDrive/video_embeddings_project/checkpoint.pkl
# Synced /content/metadata.pkl to /content/drive/MyDrive/video_embeddings_project/metadata.pkl
# Synced /content/video_embeddings.index to /content/drive/MyDrive/video_embeddings_project/video_embeddings.index
# Sync to Drive completed in 0.27s
# Checkpoint saved at batch 24
#
# Overall progress: 1000/6000 videos (16.7%)
# Elapsed time: 1.08 hours
# Estimated remaining time: 12.96 hours
# ============================================================
#
#
# ============================================================
# PROCESSING BATCH 25/60
# ============================================================
# Videos in this batch: 100
# First few videos: ['w7M1nqNAAHY', 'YYbWedRRATI', 'nkXS-O4U1gk', '-toGScaXo3g', 'W7mis_zua6g']
# RAM: 10.3/12.7 GB (84.5%)
# GPU: 448.0/15360.0 MB (2.9%)
# Batch 25: Starting processing at 20:21:29
# Downloading 100 videos sequentially (no parallelism)...
# Downloading video 1/100: w7M1nqNAAHY
# Attempting download of w7M1nqNAAHY (attempt 1/3)
# Error downloading w7M1nqNAAHY: ERROR: [youtube] w7M1nqNAAHY: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of w7M1nqNAAHY (attempt 2/3)
# Error downloading w7M1nqNAAHY: ERROR: [youtube] w7M1nqNAAHY: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of w7M1nqNAAHY (attempt 3/3)
# Error downloading w7M1nqNAAHY: ERROR: [youtube] w7M1nqNAAHY: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Max retries reached for w7M1nqNAAHY
# ✗ Failed to download w7M1nqNAAHY
# Downloading video 2/100: YYbWedRRATI
# Attempting download of YYbWedRRATI (attempt 1/3)
# Error downloading YYbWedRRATI: ERROR: [youtube] YYbWedRRATI: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of YYbWedRRATI (attempt 2/3)
# Error downloading YYbWedRRATI: ERROR: [youtube] YYbWedRRATI: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of YYbWedRRATI (attempt 3/3)
# Error downloading YYbWedRRATI: ERROR: [youtube] YYbWedRRATI: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Max retries reached for YYbWedRRATI
# ✗ Failed to download YYbWedRRATI
# Downloading video 3/100: nkXS-O4U1gk
# Attempting download of nkXS-O4U1gk (attempt 1/3)
# Error downloading nkXS-O4U1gk: ERROR: [youtube] nkXS-O4U1gk: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of nkXS-O4U1gk (attempt 2/3)
# Error downloading nkXS-O4U1gk: ERROR: [youtube] nkXS-O4U1gk: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of nkXS-O4U1gk (attempt 3/3)
# Error downloading nkXS-O4U1gk: ERROR: [youtube] nkXS-O4U1gk: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Max retries reached for nkXS-O4U1gk
# ✗ Failed to download nkXS-O4U1gk
# Downloading video 4/100: -toGScaXo3g
# Attempting download of -toGScaXo3g (attempt 1/3)
# Error downloading -toGScaXo3g: ERROR: [youtube] -toGScaXo3g: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of -toGScaXo3g (attempt 2/3)
# Error downloading -toGScaXo3g: ERROR: [youtube] -toGScaXo3g: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of -toGScaXo3g (attempt 3/3)
# Error downloading -toGScaXo3g: ERROR: [youtube] -toGScaXo3g: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Max retries reached for -toGScaXo3g
# ✗ Failed to download -toGScaXo3g
# Downloading video 5/100: W7mis_zua6g
# Attempting download of W7mis_zua6g (attempt 1/3)
# Error downloading W7mis_zua6g: ERROR: [youtube] W7mis_zua6g: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of W7mis_zua6g (attempt 2/3)
# Error downloading W7mis_zua6g: ERROR: [youtube] W7mis_zua6g: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of W7mis_zua6g (attempt 3/3)
# Error downloading W7mis_zua6g: ERROR: [youtube] W7mis_zua6g: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Max retries reached for W7mis_zua6g
# ✗ Failed to download W7mis_zua6g
# Downloading video 6/100: YyC1taqe6Ow
# Attempting download of YyC1taqe6Ow (attempt 1/3)
# Error downloading YyC1taqe6Ow: ERROR: [youtube] YyC1taqe6Ow: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of YyC1taqe6Ow (attempt 2/3)
# Error downloading YyC1taqe6Ow: ERROR: [youtube] YyC1taqe6Ow: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of YyC1taqe6Ow (attempt 3/3)
# Error downloading YyC1taqe6Ow: ERROR: [youtube] YyC1taqe6Ow: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Max retries reached for YyC1taqe6Ow
# ✗ Failed to download YyC1taqe6Ow
# Downloading video 7/100: NkY6gSA8Hl0
# Attempting download of NkY6gSA8Hl0 (attempt 1/3)
# Error downloading NkY6gSA8Hl0: ERROR: [youtube] NkY6gSA8Hl0: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of NkY6gSA8Hl0 (attempt 2/3)
# Error downloading NkY6gSA8Hl0: ERROR: [youtube] NkY6gSA8Hl0: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of NkY6gSA8Hl0 (attempt 3/3)
# Error downloading NkY6gSA8Hl0: ERROR: [youtube] NkY6gSA8Hl0: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Max retries reached for NkY6gSA8Hl0
# ✗ Failed to download NkY6gSA8Hl0
# Downloading video 8/100: Nky8hBdTeOI
# Attempting download of Nky8hBdTeOI (attempt 1/3)
# Error downloading Nky8hBdTeOI: ERROR: [youtube] Nky8hBdTeOI: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of Nky8hBdTeOI (attempt 2/3)
# Error downloading Nky8hBdTeOI: ERROR: [youtube] Nky8hBdTeOI: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of Nky8hBdTeOI (attempt 3/3)
# Error downloading Nky8hBdTeOI: ERROR: [youtube] Nky8hBdTeOI: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Max retries reached for Nky8hBdTeOI
# ✗ Failed to download Nky8hBdTeOI
# Downloading video 9/100: yYcEDUV-vuQ
# Attempting download of yYcEDUV-vuQ (attempt 1/3)
# Error downloading yYcEDUV-vuQ: ERROR: [youtube] yYcEDUV-vuQ: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of yYcEDUV-vuQ (attempt 2/3)
# Error downloading yYcEDUV-vuQ: ERROR: [youtube] yYcEDUV-vuQ: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of yYcEDUV-vuQ (attempt 3/3)
# Error downloading yYcEDUV-vuQ: ERROR: [youtube] yYcEDUV-vuQ: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Max retries reached for yYcEDUV-vuQ
# ✗ Failed to download yYcEDUV-vuQ
# Downloading video 10/100: NkyEOrQiGMQ
# Attempting download of NkyEOrQiGMQ (attempt 1/3)
# Error downloading NkyEOrQiGMQ: ERROR: [youtube] NkyEOrQiGMQ: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of NkyEOrQiGMQ (attempt 2/3)
# Error downloading NkyEOrQiGMQ: ERROR: [youtube] NkyEOrQiGMQ: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-...
# Attempting download of NkyEOrQiGMQ (attempt 3/3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-cb3104c9b480> in <cell line: 0>()
# ----> 1 run_pipeline_with_updated_checkpoint('/content/all_videos.csv', batch_size=100, video_limit=6000, force_reprocess=False)
#
# <ipython-input-21-2592507d64c2> in run_pipeline_with_updated_checkpoint(csv_path, batch_size, video_limit, force_reprocess)
#     216
#     217     # Continue with normal pipeline
# --> 218     return run_pipeline(csv_path, batch_size, video_limit, force_reprocess)
#
# <ipython-input-15-e9863b326962> in run_pipeline(csv_path, batch_size, video_limit, force_reprocess)
#     870         print(f"All results will be saved to both local storage and Google Drive")
#     871
# --> 872         index, metadata = process_all_videos(csv_path_to_use, total_videos=total_videos,
#     873                                            force_reprocess=force_reprocess)
#     874
#
# <ipython-input-15-e9863b326962> in process_all_videos(csv_path, total_videos, force_reprocess)
#     668
#     669         # STEP 1: Download videos sequentially
# --> 670         video_paths = download_videos_sequentially(batch_videos)
#     671
#     672         # STEP 2: Generate embeddings in parallel with Spark
#
# <ipython-input-15-e9863b326962> in download_videos_sequentially(video_ids)
#     360         print(f"Downloading video {idx+1}/{len(video_ids)}: {video_id}")
#     361         try:
# --> 362             path = download_video(video_id)
#     363             results[video_id] = path
#     364             if path:
#
# <ipython-input-15-e9863b326962> in download_video(video_id, retry)
#     223             print(f"Error downloading {video_id}: {result.stderr[:200]}...")
#     224             # Retry with exponential backoff
# --> 225             return download_video(video_id, retry + 1)
#     226
#     227         # Check if file was actually downloaded
#
# <ipython-input-15-e9863b326962> in download_video(video_id, retry)
#     223             print(f"Error downloading {video_id}: {result.stderr[:200]}...")
#     224             # Retry with exponential backoff
# --> 225             return download_video(video_id, retry + 1)
#     226
#     227         # Check if file was actually downloaded
#
# <ipython-input-15-e9863b326962> in download_video(video_id, retry)
#     217     try:
#     218         print(f"Attempting download of {video_id} (attempt {retry+1}/{DOWNLOAD_RETRIES})")
# --> 219         result = subprocess.run(cmd, capture_output=True, text=True)
#     220
#     221         # Check if there was an error
#
# /usr/lib/python3.11/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548     with Popen(*popenargs, **kwargs) as process:
#     549         try:
# --> 550             stdout, stderr = process.communicate(input, timeout=timeout)
#     551         except TimeoutExpired as exc:
#     552             process.kill()
#
# /usr/lib/python3.11/subprocess.py in communicate(self, input, timeout)
#    1207
#    1208             try:
# -> 1209                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1210             except KeyboardInterrupt:
#    1211                 # https://bugs.python.org/issue25942
#
# /usr/lib/python3.11/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    2113                             'failed to raise TimeoutExpired.')
#    2114
# -> 2115                     ready = selector.select(timeout)
#    2116                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2117
#
# /usr/lib/python3.11/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
def search_by_text(query, top_k=5):
    """Search for videos by text query"""
    # Load index and metadata
    if not os.path.exists(LOCAL_INDEX_PATH):
        if os.path.exists(DRIVE_INDEX_PATH):
            shutil.copy(DRIVE_INDEX_PATH, LOCAL_INDEX_PATH)
        else:
            print("ERROR: Index not found")
            return []

    # Load metadata
    metadata = load_metadata()
    if not metadata:
        print("ERROR: Metadata not found")
        return []

    # Load index
    index = faiss.read_index(LOCAL_INDEX_PATH)

    # Load model and processor
    model = CLIPModel.from_pretrained("openai/clip-vit-base-patch16")
    processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch16")

    # Generate text embedding
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    model.eval()

    with torch.no_grad():
        inputs = processor(text=[query], return_tensors="pt", padding=True).to(device)
        text_embedding = model.get_text_features(**inputs)
        text_embedding = text_embedding / text_embedding.norm(dim=-1, keepdim=True)
        text_embedding = text_embedding.cpu().numpy().astype('float32')

    # Search index
    D, I = index.search(text_embedding, top_k)

    # Prepare results
    results = []
    for i, (score, idx) in enumerate(zip(D[0], I[0])):
        if idx < len(metadata):
            entry = metadata[idx]
            video_id = entry['video_id']
            results.append({
                'rank': i+1,
                'video_id': video_id,
                'frame_idx': entry['frame_idx'],
                'score': float(score),
                'link': f"https://www.youtube.com/watch?v={video_id}"
            })

    return results

# %%
search_by_text("how to bake a cake", top_k=5)
# Out:
# [{'rank': 1,
#   'video_id': 'mFMVIt86Sdw',
#   'frame_idx': 9,
#   'score': 0.2887076735496521,
#   'link': 'https://www.youtube.com/watch?v=mFMVIt86Sdw'},
#  {'rank': 2,
#   'video_id': 'hV8H8bLDwaE',
#   'frame_idx': 5,
#   'score': 0.28833433985710144,
#   'link': 'https://www.youtube.com/watch?v=hV8H8bLDwaE'},
#  {'rank': 3,
#   'video_id': 'KqMfxhiVBtk',
#   'frame_idx': 16,
#   'score': 0.28824353218078613,
#   'link': 'https://www.youtube.com/watch?v=KqMfxhiVBtk'},
#  {'rank': 4,
#   'video_id': 'KqMfxhiVBtk',
#   'frame_idx': 18,
#   'score': 0.2874941825866699,
#   'link': 'https://www.youtube.com/watch?v=KqMfxhiVBtk'},
#  {'rank': 5,
#   'video_id': 'mFMVIt86Sdw',
#   'frame_idx': 1,
#   'score': 0.2854088842868805,
#   'link': 'https://www.youtube.com/watch?v=mFMVIt86Sdw'}]
